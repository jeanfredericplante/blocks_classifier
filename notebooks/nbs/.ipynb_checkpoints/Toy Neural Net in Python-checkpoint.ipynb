# %%
## From http://cs231n.github.io/neural-networks-case-study/#grad
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
N = 100; D = 2; K =3 ;

# %%
X= np.zeros((N*K,D)) # (x,y for our data)
y = np.zeros(N*K, dtype='uint8') # labels
np.linspace(0.0,1,N)
# Out:
# array([ 0.        ,  0.01010101,  0.02020202,  0.03030303,  0.04040404,
#         0.05050505,  0.06060606,  0.07070707,  0.08080808,  0.09090909,
#         0.1010101 ,  0.11111111,  0.12121212,  0.13131313,  0.14141414,
#         0.15151515,  0.16161616,  0.17171717,  0.18181818,  0.19191919,
#         0.2020202 ,  0.21212121,  0.22222222,  0.23232323,  0.24242424,
#         0.25252525,  0.26262626,  0.27272727,  0.28282828,  0.29292929,
#         0.3030303 ,  0.31313131,  0.32323232,  0.33333333,  0.34343434,
#         0.35353535,  0.36363636,  0.37373737,  0.38383838,  0.39393939,
#         0.4040404 ,  0.41414141,  0.42424242,  0.43434343,  0.44444444,
#         0.45454545,  0.46464646,  0.47474747,  0.48484848,  0.49494949,
#         0.50505051,  0.51515152,  0.52525253,  0.53535354,  0.54545455,
#         0.55555556,  0.56565657,  0.57575758,  0.58585859,  0.5959596 ,
#         0.60606061,  0.61616162,  0.62626263,  0.63636364,  0.64646465,
#         0.65656566,  0.66666667,  0.67676768,  0.68686869,  0.6969697 ,
#         0.70707071,  0.71717172,  0.72727273,  0.73737374,  0.74747475,
#         0.75757576,  0.76767677,  0.77777778,  0.78787879,  0.7979798 ,
#         0.80808081,  0.81818182,  0.82828283,  0.83838384,  0.84848485,
#         0.85858586,  0.86868687,  0.87878788,  0.88888889,  0.8989899 ,
#         0.90909091,  0.91919192,  0.92929293,  0.93939394,  0.94949495,
#         0.95959596,  0.96969697,  0.97979798,  0.98989899,  1.        ])

# %%
for j in xrange(K):
    ix = range(N*j, N*(j+1))
    radius = np.linspace(0.0,1,N)
    theta = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2
    X[ix] = np.c_[radius*np.sin(theta), radius*np.cos(theta)]
    y[ix] = j
# lets visualize the data:
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # Weights and bias

# %%
def init_weights():
    W = 0.01 * np.random.randn(D,K)
    W.shape
    b = np.zeros((1,K))
    return (W,b)
    (b.shape, W.shape)

# %%
X[1,:]
# Out:
# array([-0.00129945,  0.01001708])

# %%
#scores = np.dot(X,W) + b

# %%
#f = scores[1] # array of classe scores, unnormalized log probabilities

# %%
def class_probs():
    scores = np.dot(X,W) + b
    probs = np.exp(scores) / np.sum(np.exp(scores), axis=1, keepdims=True) # probabilities
    return (scores, probs)
    # np.exp(scores).shape, np.sum(np.exp(scores),axis=1).shape

# %%
len(X)
# Out:
# 300

# %% [markdown]
# # Loss calculation

# %%
# Loss
training_size = len(X)
# probs[range(training_size),y]
# probs[1,y[1]]
# probs[range(4),[0,0,0,1]]


def calc_loss():
    # selects the probability for the correct class
    correct_probs = probs[range(training_size),y] # selects the prob from correct label
    #loss is the average log probs for every training
    data_loss = -np.sum(np.log(correct_probs)) / training_size
    #regularization loss is the sum of the elementwise multiplication of the 2 matrices by reg factor
    reg_loss = 0.5*reg*np.sum(W*W)
#     print ("reg loss %.3f and data loss %.3f" % (reg_loss, data_loss))
    # H = np.array([[1,2,3], [4,5,6]]) ; print(H.shape, type(H), H*H)
    loss = data_loss+reg_loss
    return loss

# %%
# Gradients
# Pyi notations denotes prob for lith row. fk is the score for class k
# dL / dfk (loss wrt to class k)
# softmax max the gradient linear with respect to loss
def calc_gradients():
    class_prob = np.zeros((training_size,K))
    class_prob[range(training_size),y] = 1
    dl_dprobs = probs - class_prob
    dscores = dl_dprobs / training_size # loss is the average over all examples
    dW = np.dot(X.T, dscores) # delta on the items
    db = np.sum(dscores, axis=0, keepdims=True) # adds on dimension 0 for all samples
    dreg = reg*W # reason for having 0.5
    dW += dreg
    return (dW,db)
#     print(db,dreg)

# %%
def param_update():
    W = W - step_size*dW
    b = b -  step_size*db

# %% [markdown]
# # Fit

# %%
step_size = 0.9; reg = 0.001; sim_steps = 200

# %%
(W,b)=init_weights()
for i in xrange(sim_steps):
    (scores, probs) = class_probs()
    loss = calc_loss()
    (dW, db) = calc_gradients()
    print("iteration %d, loss %f" % (i,loss))
    W += -step_size * dW
    b += -step_size * db
# Out:
# iteration 0, loss 1.097772
# iteration 1, loss 1.071666
# iteration 2, loss 1.048160
# iteration 3, loss 1.026967
# iteration 4, loss 1.007828
# iteration 5, loss 0.990516
# iteration 6, loss 0.974828
# iteration 7, loss 0.960588
# iteration 8, loss 0.947635
# iteration 9, loss 0.935832
# iteration 10, loss 0.925056
# iteration 11, loss 0.915200
# iteration 12, loss 0.906168
# iteration 13, loss 0.897876
# iteration 14, loss 0.890250
# iteration 15, loss 0.883225
# iteration 16, loss 0.876744
# iteration 17, loss 0.870753
# iteration 18, loss 0.865208
# iteration 19, loss 0.860068
# iteration 20, loss 0.855296
# iteration 21, loss 0.850860
# iteration 22, loss 0.846732
# iteration 23, loss 0.842884
# iteration 24, loss 0.839293
# iteration 25, loss 0.835938
# iteration 26, loss 0.832801
# iteration 27, loss 0.829863
# iteration 28, loss 0.827110
# iteration 29, loss 0.824527
# iteration 30, loss 0.822101
# iteration 31, loss 0.819821
# iteration 32, loss 0.817676
# iteration 33, loss 0.815655
# iteration 34, loss 0.813752
# iteration 35, loss 0.811956
# iteration 36, loss 0.810261
# iteration 37, loss 0.808660
# iteration 38, loss 0.807147
# iteration 39, loss 0.805716
# iteration 40, loss 0.804361
# iteration 41, loss 0.803077
# iteration 42, loss 0.801861
# iteration 43, loss 0.800708
# iteration 44, loss 0.799613
# iteration 45, loss 0.798574
# iteration 46, loss 0.797587
# iteration 47, loss 0.796649
# iteration 48, loss 0.795757
# iteration 49, loss 0.794908
# iteration 50, loss 0.794101
# iteration 147, loss 0.775985
# iteration 148, loss 0.775965
# iteration 149, loss 0.775947
# iteration 150, loss 0.775928
# iteration 151, loss 0.775911
# iteration 152, loss 0.775894
# iteration 153, loss 0.775877
# iteration 154, loss 0.775861
# iteration 155, loss 0.775845
# iteration 156, loss 0.775830
# iteration 157, loss 0.775816
# iteration 158, loss 0.775802
# iteration 159, loss 0.775788
# iteration 160, loss 0.775775
# iteration 161, loss 0.775762
# iteration 162, loss 0.775750
# iteration 163, loss 0.775738
# iteration 164, loss 0.775726
# iteration 165, loss 0.775715
# iteration 166, loss 0.775704
# iteration 167, loss 0.775693
# iteration 168, loss 0.775683
# iteration 169, loss 0.775673
# iteration 170, loss 0.775663
# iteration 171, loss 0.775654
# iteration 172, loss 0.775645
# iteration 173, loss 0.775636
# iteration 174, loss 0.775628
# iteration 175, loss 0.775620
# iteration 176, loss 0.775612
# iteration 177, loss 0.775604
# iteration 178, loss 0.775596
# iteration 179, loss 0.775589
# iteration 180, loss 0.775582
# iteration 181, loss 0.775575
# iteration 182, loss 0.775569
# iteration 183, loss 0.775562
# iteration 184, loss 0.775556
# iteration 185, loss 0.775550
# iteration 186, loss 0.775544
# iteration 187, loss 0.775539
# iteration 188, loss 0.775533
# iteration 189, loss 0.775528
# iteration 190, loss 0.775523
# iteration 191, loss 0.775518
# iteration 192, loss 0.775513
# iteration 193, loss 0.775508
# iteration 194, loss 0.775503
# iteration 195, loss 0.775499
# iteration 196, loss 0.775495
# iteration 197, loss 0.775491
# iteration 198, loss 0.775487
# iteration 199, loss 0.775483

# %% [markdown]
# # Evaluate

# %%
scores = np.dot(X,W) + b
evaluated_class = np.argmax(scores, axis = 1)
np.mean(evaluated_class == y)
# Out:
# 0.50666666666666671

# %% [markdown]
# # with 1 hidden layer

# %%
def init_weights(h):
    # h hidden layer size
    W = 0.01 * np.random.randn(D,h)
    W2 = 0.01 * np.random.randn(h,K)
    b = np.zeros((1,h))
    b2 = np.zeros((1,K))
    return (W,b, W2,b2)

# %%
(W,b, W2,b2) = init_weights(100)

# %%
def forward_pass():
    # X > (W,b) hidden (reLU) > (W2,b2) scores > probs
    hidden = np.dot(X,W) + b # hidden activations
    hidden[np.where(hidden <=0)] = 0 # np.maximum alternative. ReLU
    scores = np.dot(hidden,W2) + b2 # score
    probs = np.exp(scores) / np.sum(np.exp(scores), axis = 1, keepdims = True)
    correct_probs = probs[range(training_size),y] # selects the prob from correct label
    # Loss calc
    data_loss = -np.sum(np.log(correct_probs)) / training_size
    reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
    loss = data_loss+reg_loss
    return (scores, probs, hidden, loss)

# %%
def backward_pass():
    dscores = probs # dloss / dscores
    dscores[range(training_size),y] -= 1 
    dscores = dscores / training_size # loss is the average over all examples
    dW2 = np.dot(hidden.T, dscores) # delta on the items
    db2 = np.sum(dscores, axis=0, keepdims=True) # adds on dimension 0 for all samples
    dreg2 = reg*W2 # reason for having 0.5
    dW2 += dreg2
    dhidden = np.dot(dscores, W2.T) # dhidden / dscores
    dhidden[hidden <=0] = 0 # reLU deactivate hidden
    dW = np.dot(X.T, dhidden) # dw / dhidden
    db = np.sum(dhidden, axis=0, keepdims=True) # adds on dimension 0 for all samples
    return (dW,db,dW2, db2)

# %%
def update_params(W,b,W2,b2,dW,db,dW2,db2):
    W += -step_size * dW
    b += -step_size * db
    W2 += -step_size * dW2
    b2 += -step_size * db2
    return (W,b,W2,b2)

# %%
step_size = 0.1; reg = 0.001; sim_steps = 20000

# %%
(W,b, W2,b2) = init_weights(100)
for i in xrange(sim_steps):
    (scores, probs, hidden, loss) = forward_pass()
    (dW,db,dW2, db2) = backward_pass()
    (W,b,W2,b2) = update_params(W,b,W2,b2,dW,db,dW2,db2)
    if i % 400 == 0:
        print("iteration %d, loss %f" % (i,loss))
# Out:
# iteration 0, loss 1.098602
# iteration 400, loss 0.808432
# iteration 800, loss 0.726945
# iteration 1200, loss 0.706493
# iteration 1600, loss 0.681155
# iteration 2000, loss 0.642822
# iteration 2400, loss 0.589979
# iteration 2800, loss 0.528467
# iteration 3200, loss 0.472502
# iteration 3600, loss 0.430560
# iteration 4000, loss 0.401870
# iteration 4400, loss 0.382913
# iteration 4800, loss 0.369814
# iteration 5200, loss 0.360547
# iteration 5600, loss 0.353735
# iteration 6000, loss 0.348146
# iteration 6400, loss 0.343752
# iteration 6800, loss 0.339590
# iteration 7200, loss 0.336127
# iteration 7600, loss 0.332938
# iteration 8000, loss 0.330095
# iteration 8400, loss 0.327047
# iteration 8800, loss 0.324368
# iteration 9200, loss 0.322116
# iteration 9600, loss 0.320224
# iteration 10000, loss 0.318585
# iteration 10400, loss 0.317285
# iteration 10800, loss 0.316316
# iteration 11200, loss 0.315526
# iteration 11600, loss 0.314844
# iteration 12000, loss 0.314550
# iteration 12400, loss 0.314587
# iteration 12800, loss 0.314890
# iteration 13200, loss 0.315432
# iteration 13600, loss 0.316148
# iteration 14000, loss 0.317049
# iteration 14400, loss 0.318146
# iteration 14800, loss 0.319405
# iteration 15200, loss 0.320797
# iteration 15600, loss 0.322328
# iteration 16000, loss 0.323979
# iteration 16400, loss 0.325798
# iteration 16800, loss 0.327716
# iteration 17200, loss 0.329720
# iteration 17600, loss 0.331812
# iteration 18000, loss 0.333973
# iteration 18400, loss 0.336179
# iteration 18800, loss 0.338430
# iteration 19200, loss 0.340729
# iteration 19600, loss 0.343072

# %% [markdown]
# # Evaluate

# %%
hidden_layer = np.maximum(0,np.dot(X,W) + b)
scores = np.dot(hidden_layer,W2) + b2
evaluated_class = np.argmax(scores, axis = 1)
np.mean(evaluated_class == y)
# Out:
# 0.98666666666666669
