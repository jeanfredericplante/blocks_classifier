# %%
## From http://cs231n.github.io/neural-networks-case-study/#grad
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
N = 100; D = 2; K =3 ;

# %%
X= np.zeros((N*K,D)) # (x,y for our data)
y = np.zeros(N*K, dtype='uint8') # labels
np.linspace(0.0,1,N)
# Out:
# array([ 0.        ,  0.01010101,  0.02020202,  0.03030303,  0.04040404,
#         0.05050505,  0.06060606,  0.07070707,  0.08080808,  0.09090909,
#         0.1010101 ,  0.11111111,  0.12121212,  0.13131313,  0.14141414,
#         0.15151515,  0.16161616,  0.17171717,  0.18181818,  0.19191919,
#         0.2020202 ,  0.21212121,  0.22222222,  0.23232323,  0.24242424,
#         0.25252525,  0.26262626,  0.27272727,  0.28282828,  0.29292929,
#         0.3030303 ,  0.31313131,  0.32323232,  0.33333333,  0.34343434,
#         0.35353535,  0.36363636,  0.37373737,  0.38383838,  0.39393939,
#         0.4040404 ,  0.41414141,  0.42424242,  0.43434343,  0.44444444,
#         0.45454545,  0.46464646,  0.47474747,  0.48484848,  0.49494949,
#         0.50505051,  0.51515152,  0.52525253,  0.53535354,  0.54545455,
#         0.55555556,  0.56565657,  0.57575758,  0.58585859,  0.5959596 ,
#         0.60606061,  0.61616162,  0.62626263,  0.63636364,  0.64646465,
#         0.65656566,  0.66666667,  0.67676768,  0.68686869,  0.6969697 ,
#         0.70707071,  0.71717172,  0.72727273,  0.73737374,  0.74747475,
#         0.75757576,  0.76767677,  0.77777778,  0.78787879,  0.7979798 ,
#         0.80808081,  0.81818182,  0.82828283,  0.83838384,  0.84848485,
#         0.85858586,  0.86868687,  0.87878788,  0.88888889,  0.8989899 ,
#         0.90909091,  0.91919192,  0.92929293,  0.93939394,  0.94949495,
#         0.95959596,  0.96969697,  0.97979798,  0.98989899,  1.        ])

# %%
for j in xrange(K):
    ix = range(N*j, N*(j+1))
    radius = np.linspace(0.0,1,N)
    theta = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2
    X[ix] = np.c_[radius*np.sin(theta), radius*np.cos(theta)]
    y[ix] = j
# lets visualize the data:
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # Weights and bias

# %%
def init_weights():
    W = 0.01 * np.random.randn(D,K)
    W.shape
    b = np.zeros((1,K))
    return (W,b)
    (b.shape, W.shape)

# %%
X[1,:]
# Out:
# array([-0.00304462,  0.00963124])

# %%
#scores = np.dot(X,W) + b

# %%
#f = scores[1] # array of classe scores, unnormalized log probabilities

# %%
def class_probs():
    scores = np.dot(X,W) + b
    probs = np.exp(scores) / np.sum(np.exp(scores), axis=1, keepdims=True) # probabilities
    return (scores, probs)
    # np.exp(scores).shape, np.sum(np.exp(scores),axis=1).shape

# %%
len(X)
# Out:
# 300

# %% [markdown]
# # Loss calculation

# %%
# Loss
training_size = len(X)
# probs[range(training_size),y]
# probs[1,y[1]]
# probs[range(4),[0,0,0,1]]


def calc_loss():
    # selects the probability for the correct class
    correct_probs = probs[range(training_size),y] # selects the prob from correct label
    #loss is the average log probs for every training
    data_loss = -np.sum(np.log(correct_probs)) / training_size
    #regularization loss is the sum of the elementwise multiplication of the 2 matrices by reg factor
    reg_loss = 0.5*reg*np.sum(W*W)
#     print ("reg loss %.3f and data loss %.3f" % (reg_loss, data_loss))
    # H = np.array([[1,2,3], [4,5,6]]) ; print(H.shape, type(H), H*H)
    loss = data_loss+reg_loss
    return loss

# %%
# Gradients
# Pyi notations denotes prob for lith row. fk is the score for class k
# dL / dfk (loss wrt to class k)
# softmax max the gradient linear with respect to loss
def calc_gradients():
    class_prob = np.zeros((training_size,K))
    class_prob[range(training_size),y] = 1
    dl_dprobs = probs - class_prob
    dscores = dl_dprobs / training_size # loss is the average over all examples
    dW = np.dot(X.T, dscores) # delta on the items
    db = np.sum(dscores, axis=0, keepdims=True) # adds on dimension 0 for all samples
    dreg = reg*W # reason for having 0.5
    dW += dreg
    return (dW,db)
#     print(db,dreg)

# %%
def param_update():
    W = W - step_size*dW
    b = b -  step_size*db

# %% [markdown]
# # Fit

# %%
step_size = 0.9; reg = 0.001; sim_steps = 200

# %%
(W,b)=init_weights()
for i in xrange(sim_steps):
    (scores, probs) = class_probs()
    loss = calc_loss()
    (dW, db) = calc_gradients()
    print("iteration %d, loss %f" % (i,loss))
    W += -step_size * dW
    b += -step_size * db
# Out:
# iteration 0, loss 1.098577
# iteration 1, loss 1.071159
# iteration 2, loss 1.046462
# iteration 3, loss 1.024187
# iteration 4, loss 1.004064
# iteration 5, loss 0.985856
# iteration 6, loss 0.969352
# iteration 7, loss 0.954364
# iteration 8, loss 0.940728
# iteration 9, loss 0.928297
# iteration 10, loss 0.916945
# iteration 11, loss 0.906556
# iteration 12, loss 0.897032
# iteration 13, loss 0.888285
# iteration 14, loss 0.880237
# iteration 15, loss 0.872819
# iteration 16, loss 0.865970
# iteration 17, loss 0.859637
# iteration 18, loss 0.853770
# iteration 19, loss 0.848328
# iteration 20, loss 0.843273
# iteration 21, loss 0.838569
# iteration 22, loss 0.834188
# iteration 23, loss 0.830100
# iteration 24, loss 0.826283
# iteration 25, loss 0.822713
# iteration 26, loss 0.819370
# iteration 27, loss 0.816238
# iteration 28, loss 0.813298
# iteration 29, loss 0.810537
# iteration 30, loss 0.807942
# iteration 31, loss 0.805499
# iteration 32, loss 0.803197
# iteration 33, loss 0.801028
# iteration 34, loss 0.798980
# iteration 35, loss 0.797047
# iteration 36, loss 0.795219
# iteration 37, loss 0.793490
# iteration 38, loss 0.791853
# iteration 39, loss 0.790303
# iteration 40, loss 0.788834
# iteration 41, loss 0.787440
# iteration 42, loss 0.786116
# iteration 43, loss 0.784859
# iteration 44, loss 0.783665
# iteration 45, loss 0.782529
# iteration 46, loss 0.781448
# iteration 47, loss 0.780420
# iteration 48, loss 0.779440
# iteration 49, loss 0.778506
# iteration 50, loss 0.777616
# iteration 51, loss 0.776766
# iteration 52, loss 0.775956
# iteration 53, loss 0.775182
# iteration 54, loss 0.774442
# iteration 55, loss 0.773736
# iteration 56, loss 0.773061
# iteration 57, loss 0.772415
# iteration 58, loss 0.771797
# iteration 59, loss 0.771205
# iteration 60, loss 0.770639
# iteration 61, loss 0.770096
# iteration 62, loss 0.769577
# iteration 63, loss 0.769078
# iteration 64, loss 0.768601
# iteration 65, loss 0.768143
# iteration 66, loss 0.767703
# iteration 67, loss 0.767281
# iteration 68, loss 0.766876
# iteration 69, loss 0.766487
# iteration 70, loss 0.766114
# iteration 71, loss 0.765755
# iteration 72, loss 0.765410
# iteration 73, loss 0.765079
# iteration 74, loss 0.764760
# iteration 75, loss 0.764453
# iteration 76, loss 0.764158
# iteration 77, loss 0.763874
# iteration 78, loss 0.763601
# iteration 79, loss 0.763338
# iteration 80, loss 0.763085
# iteration 81, loss 0.762841
# iteration 82, loss 0.762606
# iteration 83, loss 0.762380
# iteration 84, loss 0.762162
# iteration 85, loss 0.761951
# iteration 199, loss 0.755896

# %% [markdown]
# # Evaluate

# %%
scores = np.dot(X,W) + b
evaluated_class = np.argmax(scores, axis = 1)
np.mean(evaluated_class == y)
# Out:
# 0.51000000000000001

# %% [markdown]
# # with 1 hidden layer

# %%
def init_weights(h):
    # h hidden layer size
    W = 0.01 * np.random.randn(D,h)
    W2 = 0.01 * np.random.randn(h,K)
    b = np.zeros((1,h))
    b2 = np.zeros((1,K))
    return (W,b, W2,b2)

# %%
(W,b, W2,b2) = init_weights(100)

# %%
def forward_pass():
    # X > (W,b) hidden (reLU) > (W2,b2) scores > probs
    hidden = np.dot(X,W) + b # hidden activations
    hidden[np.where(hidden <=0)] = 0 # np.maximum alternative. ReLU
    scores = np.dot(hidden,W2) + b2 # score
    probs = np.exp(scores) / np.sum(np.exp(scores), axis = 1, keepdims = True)
    correct_probs = probs[range(training_size),y] # selects the prob from correct label
    # Loss calc
    data_loss = -np.sum(np.log(correct_probs)) / training_size
    reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
    loss = data_loss+reg_loss
    return (scores, probs, hidden, loss)

# %%
def backward_pass():
    dscores = probs # dloss / dscores
    dscores[range(training_size),y] -= 1 
    dscores = dscores / training_size # loss is the average over all examples
    dW2 = np.dot(hidden.T, dscores) # delta on the items
    db2 = np.sum(dscores, axis=0, keepdims=True) # adds on dimension 0 for all samples
    dreg2 = reg*W2 # reason for having 0.5
    dW2 += dreg2
    dhidden = np.dot(dscores, W2.T) # dhidden / dscores
    dhidden[hidden <=0] = 0 # reLU deactivate hidden
    dW = np.dot(X.T, dhidden) + reg*W # dw / dhidden + reg impact
    db = np.sum(dhidden, axis=0, keepdims=True) # adds on dimension 0 for all samples
    return (dW,db,dW2, db2)

# %%
def update_params(W,b,W2,b2,dW,db,dW2,db2):
    W += -step_size * dW
    b += -step_size * db
    W2 += -step_size * dW2
    b2 += -step_size * db2
    return (W,b,W2,b2)

# %%
step_size = 1; reg = 0.001; sim_steps = 10000

# %%
(W,b, W2,b2) = init_weights(100)
for i in xrange(sim_steps):
    (scores, probs, hidden, loss) = forward_pass()
    (dW,db,dW2, db2) = backward_pass()
    (W,b,W2,b2) = update_params(W,b,W2,b2,dW,db,dW2,db2)
    if i % 400 == 0:
        print("iteration %d, loss %f" % (i,loss))
# Out:
# iteration 0, loss 1.098780
# iteration 400, loss 0.399351
# iteration 800, loss 0.306011
# iteration 1200, loss 0.281738
# iteration 1600, loss 0.308040
# iteration 2000, loss 0.271910
# iteration 2400, loss 0.266895
# iteration 2800, loss 0.259116
# iteration 3200, loss 0.252984
# iteration 3600, loss 0.249605
# iteration 4000, loss 0.247825
# iteration 4400, loss 0.246756
# iteration 4800, loss 0.246012
# iteration 5200, loss 0.245402
# iteration 5600, loss 0.244940
# iteration 6000, loss 0.244550
# iteration 6400, loss 0.244233
# iteration 6800, loss 0.243999
# iteration 7200, loss 0.243861
# iteration 7600, loss 0.243766
# iteration 8000, loss 0.243691
# iteration 8400, loss 0.243642
# iteration 8800, loss 0.243605
# iteration 9200, loss 0.243576
# iteration 9600, loss 0.243556

# %% [markdown]
# # Evaluate

# %%
hidden_layer = np.maximum(0,np.dot(X,W) + b)
scores = np.dot(hidden_layer,W2) + b2
evaluated_class = np.argmax(scores, axis = 1)
np.mean(evaluated_class == y)
# Out:
# 0.98333333333333328
