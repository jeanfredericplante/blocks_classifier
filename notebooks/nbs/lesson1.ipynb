# %% [markdown]
# # Using Convolutional Neural Networks

# %% [markdown]
# Welcome to the first week of the first deep learning certificate! We're going to use convolutional neural networks (CNNs) to allow our computer to see - something that is only possible thanks to deep learning.

# %% [markdown]
# ## Introduction to this week's task: 'Dogs vs Cats'

# %% [markdown]
# We're going to try to create a model to enter the [Dogs vs Cats](https://www.kaggle.com/c/dogs-vs-cats) competition at Kaggle. There are 25,000 labelled dog and cat photos available for training, and 12,500 in the test set that we have to try to label for this competition. According to the Kaggle web-site, when this competition was launched (end of 2013): *"**State of the art**: The current literature suggests machine classifiers can score above 80% accuracy on this task"*. So if we can beat 80%, then we will be at the cutting edge as of 2013!

# %% [markdown]
# ## Basic setup

# %% [markdown]
# There isn't too much to do to get started - just a few simple configuration steps.
#
# This shows plots in the web page itself - we always wants to use this when using jupyter notebook:

# %%
# %matplotlib inline

# %% [markdown]
# Define path to data: (It's a good idea to put it in a subdirectory of your notebooks folder, and then exclude that directory from git control by adding it to .gitignore.)

# %%
path = "/srv/"
#path = "data/dogscats/sample/"

# %% [markdown]
# A few basic libraries that we'll need for the initial exercises:

# %%
from __future__ import division,print_function

import os, json
from glob import glob
import numpy as np
np.set_printoptions(precision=4, linewidth=100)
from matplotlib import pyplot as plt

# %% [markdown]
# We have created a file most imaginatively called 'utils.py' to store any little convenience functions we'll want to use. We will discuss these as we use them.

# %%
import utils; reload(utils)
from utils import plots
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Use a pretrained VGG model with our **Vgg16** class

# %% [markdown]
# Our first step is simply to use a model that has been fully created for us, which can recognise a wide variety (1,000 categories) of images. We will use 'VGG', which won the 2014 Imagenet competition, and is a very simple model to create and understand. The VGG Imagenet team created both a larger, slower, slightly more accurate model (*VGG  19*) and a smaller, faster model (*VGG 16*). We will be using VGG 16 since the much slower performance of VGG19 is generally not worth the very minor improvement in accuracy.
#
# We have created a python class, *Vgg16*, which makes using the VGG 16 model very straightforward.

# %% [markdown]
# ## The punchline: state of the art custom model in 7 lines of code
#
# Here's everything you need to do to get >97% accuracy on the Dogs vs Cats dataset - we won't analyze how it works behind the scenes yet, since at this stage we're just going to focus on the minimum necessary to actually do useful work.

# %%
# As large as you can, but no larger than 64 is recommended. 
# If you have an older or cheaper GPU, you'll run out of memory, so will have to decrease this.
batch_size=8

# %%
# Import our class, and instantiate
import vgg16; reload(vgg16)
from vgg16 import Vgg16

# %%
vgg = Vgg16()
# Grab a few images at a time for training and validation.
# NB: They must be in subdirectories named based on their category
batches = vgg.get_batches(path+'training', batch_size=batch_size)
val_batches = vgg.get_batches(path+'valid', batch_size=batch_size*2)
vgg.finetune(batches)
vgg.fit(batches, val_batches, nb_epoch=1)
# Out:
# Found 633 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Epoch 1/1
# 633/633 [==============================] - 949s - loss: 0.2875 - acc: 0.8799 - val_loss: 0.0403 - val_acc: 0.9773

# %% [markdown]
# The code above will work for any image recognition task, with any number of categories! All you have to do is to put your images into one folder per category, and run the code above.
#
# Let's take a look at how this works, step by step...

# %% [markdown]
# ## Use Vgg16 for basic image recognition
#
# Let's start off by using the *Vgg16* class to recognise the main imagenet category for each image.
#
# We won't be able to enter the Cats vs Dogs competition with an Imagenet model alone, since 'cat' and 'dog' are not categories in Imagenet - instead each individual breed is a separate category. However, we can use it to see how well it can recognise the images, which is a good first step.
#
# First, create a Vgg16 object:

# %%
vgg = Vgg16()

# %%
vgg.model.layers.pop(0)

# %%
vgg.model.layers
# Out:
# [<keras.layers.convolutional.ZeroPadding2D at 0x7f8208ebfe10>,
#  <keras.layers.convolutional.Convolution2D at 0x7f8208add5d0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f82089bfcd0>,
#  <keras.layers.convolutional.Convolution2D at 0x7f82089bff10>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f8208ebfdd0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f820892b850>,
#  <keras.layers.convolutional.Convolution2D at 0x7f820894e4d0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f82088df890>,
#  <keras.layers.convolutional.Convolution2D at 0x7f82088dfb50>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f820892bb10>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f8208910550>,
#  <keras.layers.convolutional.Convolution2D at 0x7f82088b91d0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f82088ca590>,
#  <keras.layers.convolutional.Convolution2D at 0x7f82088ca7d0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f820886fbd0>,
#  <keras.layers.convolutional.Convolution2D at 0x7f8208883990>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f8208910310>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f8208828d10>,
#  <keras.layers.convolutional.Convolution2D at 0x7f820884c910>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f82087e0dd0>,
#  <keras.layers.convolutional.Convolution2D at 0x7f82087f36d0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f8208817750>,
#  <keras.layers.convolutional.Convolution2D at 0x7f82088178d0>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f8208828bd0>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f82087cf410>,
#  <keras.layers.convolutional.Convolution2D at 0x7f8208776190>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f8208788450>,
#  <keras.layers.convolutional.Convolution2D at 0x7f8208788690>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x7f820872f910>,
#  <keras.layers.convolutional.Convolution2D at 0x7f8208745850>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f82087cf1d0>,
#  <keras.layers.core.Flatten at 0x7f82086e6a90>,
#  <keras.layers.core.Dense at 0x7f820870eb10>,
#  <keras.layers.core.Dropout at 0x7f82086b6890>,
#  <keras.layers.core.Dense at 0x7f82086b6510>,
#  <keras.layers.core.Dropout at 0x7f8208674a50>,
#  <keras.layers.core.Dense at 0x7f82086746d0>]

# %% [markdown]
# Vgg16 is built on top of *Keras* (which we will be learning much more about shortly!), a flexible, easy to use deep learning library that sits on top of Theano or Tensorflow. Keras reads groups of images and labels in *batches*, using a fixed directory structure, where images from each category for training must be placed in a separate folder.
#
# Let's grab batches of data from our training folder:

# %%
batches = vgg.get_batches(path+'training', batch_size=4)
# Out:
# Found 633 images belonging to 2 classes.

# %% [markdown]
# (BTW, when Keras refers to 'classes', it doesn't mean python classes - but rather it refers to the categories of the labels, such as 'pug', or 'tabby'.)
#
# *Batches* is just a regular python iterator. Each iteration returns both the images themselves, as well as the labels.

# %%
imgs,labels = next(batches)

# %% [markdown]
# As you can see, the labels for each image are an array, containing a 1 in the first position if it's a cat, and in the second position if it's a dog. This approach to encoding categorical variables, where an array containing just a single 1 in the position corresponding to the category, is very common in deep learning. It is called *one hot encoding*.
#
# The arrays contain two elements, because we have two categories (cat, and dog). If we had three categories (e.g. cats, dogs, and kangaroos), then the arrays would each contain two 0's, and one 1.

# %%
plots(imgs, titles=labels)

# %% [markdown]
# We can now pass the images to Vgg16's predict() function to get back probabilities, category indexes, and category names for each image's VGG prediction.

# %%
vgg.predict(imgs, True)
# Out:
# (array([ 0.4557,  0.3849,  0.224 ,  0.5816], dtype=float32),
#  array([549, 769, 709, 844]),
#  [u'envelope', u'rule', u'pencil_box', u'switch'])

# %% [markdown]
# The category indexes are based on the ordering of categories used in the VGG model - e.g here are the first four:

# %%
vgg.classes[:4]
# Out:
# [u'tench', u'goldfish', u'great_white_shark', u'tiger_shark']

# %% [markdown]
# (Note that, other than creating the Vgg16 object, none of these steps are necessary to build a model; they are just showing how to use the class to view imagenet predictions.)

# %% [markdown]
# ## Use our Vgg16 class to finetune a Dogs vs Cats model
#
# To change our model so that it outputs "cat" vs "dog", instead of one of 1,000 very specific categories, we need to use a process called "finetuning". Finetuning looks from the outside to be identical to normal machine learning training - we provide a training set with data and labels to learn from, and a validation set to test against. The model learns a set of parameters based on the data provided.
#
# However, the difference is that we start with a model that is already trained to solve a similar problem. The idea is that many of the parameters should be very similar, or the same, between the existing model, and the model we wish to create. Therefore, we only select a subset of parameters to train, and leave the rest untouched. This happens automatically when we call *fit()* after calling *finetune()*.
#
# We create our batches just like before, and making the validation set available as well. A 'batch' (or *mini-batch* as it is commonly known) is simply a subset of the training data - we use a subset at a time when training or predicting, in order to speed up training, and to avoid running out of memory.

# %%
batch_size=8

# %%
batches = vgg.get_batches(path+'training', batch_size=batch_size)
val_batches = vgg.get_batches(path+'valid', batch_size=batch_size)
# Out:
# Found 633 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.

# %% [markdown]
# Calling *finetune()* modifies the model such that it will be trained based on the data in the batches provided - in this case, to predict either 'dog' or 'cat'.

# %%
vgg.finetune(batches)

# %% [markdown]
# Finally, we *fit()* the parameters of the model using the training data, reporting the accuracy on the validation set after every epoch. (An *epoch* is one full pass through the training data.)

# %%
vgg.fit(batches, val_batches, nb_epoch=1)
# Out:
# Epoch 1/1
# 633/633 [==============================] - 877s - loss: 0.2816 - acc: 0.8815 - val_loss: 0.0842 - val_acc: 0.9659

# %% [markdown]
# That shows all of the steps involved in using the Vgg16 class to create an image recognition model using whatever labels you are interested in. For instance, this process could classify paintings by style, or leaves by type of disease, or satellite photos by type of crop, and so forth.
#
# Next up, we'll dig one level deeper to see what's going on in the Vgg16 class.

# %% [markdown]
# ### Saving the weights of my model in vgg_jf.h5 file (vgg.save_weights())

# %% [markdown]
# # Saving the model to CoreML Format

# %% [markdown]
# CoreML converter requires Keras 1.2.2 and TensorFlow 1.0.0.

# %%
import coremltools

# %% [markdown]
# coreml_model = coremltools.converters.keras.convert(vgg.model, input_names = 'image', class_labels  = ['one','ten'])

# %%
coreml_model = coremltools.converters.keras

# %%
from coremltools.converters.keras._keras_converter import convert

# %%
help(coreml_model)
# Out:
# Help on package coremltools.converters.keras in coremltools.converters:
#
# NAME
#     coremltools.converters.keras
#
# FILE
#     /usr/local/lib/python2.7/dist-packages/coremltools/converters/keras/__init__.py
#
# DESCRIPTION
#     # Copyright (c) 2017, Apple Inc. All rights reserved.
#     #
#     # Use of this source code is governed by a BSD-3-clause license that can be
#     # found in the LICENSE.txt file or at https://opensource.org/licenses/BSD-3-Clause
#
# PACKAGE CONTENTS
#     _keras2_converter
#     _keras_converter
#     _layers
#     _layers2
#     _topology
#     _topology2
#     _utils

# %%
convert(vgg.model)
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-59-2e8608c78307> in <module>()
# ----> 1 convert(vgg.model)
#
# /usr/local/lib/python2.7/dist-packages/coremltools/converters/keras/_keras_converter.pyc in convert(model, input_names, output_names, image_input_names, is_bgr, red_bias, green_bias, blue_bias, gray_bias, image_scale, class_labels, predicted_feature_name, predicted_probabilities_output)
#     504                                    predicted_probabilities_output = predicted_probabilities_output)
#     505     else:
# --> 506         raise RuntimeError('keras not found or unsupported version or backend found. keras conversion API is disabled.')
#     507         return None
#
# RuntimeError: keras not found or unsupported version or backend found. keras conversion API is disabled.

# %% [markdown]
# AttributeErrorTraceback (most recent call last)
# <ipython-input-46-04748801d649> in <module>()
# ----> 1 coreml_model.convert(vgg.model)
#
# AttributeError: 'module' object has no attribute 'convert'

# %%
coreml_model.save('one_ten_categorization.mlmodel')

# %% [markdown]
# # Create a VGG model from scratch in Keras
#
# For the rest of this tutorial, we will not be using the Vgg16 class at all. Instead, we will recreate from scratch the functionality we just used. This is not necessary if all you want to do is use the existing model - but if you want to create your own models, you'll need to understand these details. It will also help you in the future when you debug any problems with your models, since you'll understand what's going on behind the scenes.

# %% [markdown]
# ## Model setup
#
# We need to import all the modules we'll be using from numpy, scipy, and keras:

# %%
from numpy.random import random, permutation
from scipy import misc, ndimage
from scipy.ndimage.interpolation import zoom

import keras
from keras import backend as K
from keras.utils.data_utils import get_file
from keras.models import Sequential, Model
from keras.layers.core import Flatten, Dense, Dropout, Lambda
from keras.layers import Input
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, RMSprop
from keras.preprocessing import image

# %% [markdown]
# Let's import the mappings from VGG ids to imagenet category ids and descriptions, for display purposes later.

# %%
FILES_PATH = 'http://files.fast.ai/models/'; CLASS_FILE='imagenet_class_index.json'
# Keras' get_file() is a handy function that downloads files, and caches them for re-use later
fpath = get_file(CLASS_FILE, FILES_PATH+CLASS_FILE, cache_subdir='models')
with open(fpath) as f: class_dict = json.load(f)
# Convert dictionary with string indexes into an array
classes = [class_dict[str(i)][1] for i in range(len(class_dict))]

# %% [markdown]
# Here's a few examples of the categories we just imported:

# %%
classes[:5]
# Out:
# [u'tench', u'goldfish', u'great_white_shark', u'tiger_shark', u'hammerhead']

# %%
class_dict
# Out:
# {u'344': [u'n02398521', u'hippopotamus'],
#  u'0': [u'n01440764', u'tench'],
#  u'346': [u'n02408429', u'water_buffalo'],
#  u'347': [u'n02410509', u'bison'],
#  u'340': [u'n02391049', u'zebra'],
#  u'341': [u'n02395406', u'hog'],
#  u'342': [u'n02396427', u'wild_boar'],
#  u'343': [u'n02397096', u'warthog'],
#  u'810': [u'n04264628', u'space_bar'],
#  u'811': [u'n04265275', u'space_heater'],
#  u'812': [u'n04266014', u'space_shuttle'],
#  u'813': [u'n04270147', u'spatula'],
#  u'348': [u'n02412080', u'ram'],
#  u'349': [u'n02415577', u'bighorn'],
#  u'816': [u'n04277352', u'spindle'],
#  u'817': [u'n04285008', u'sports_car'],
#  u'595': [u'n03496892', u'harvester'],
#  u'719': [u'n03935335', u'piggy_bank'],
#  u'718': [u'n03933933', u'pier'],
#  u'717': [u'n03930630', u'pickup'],
#  u'716': [u'n03930313', u'picket_fence'],
#  u'715': [u'n03929855', u'pickelhaube'],
#  u'714': [u'n03929660', u'pick'],
#  u'713': [u'n03924679', u'photocopier'],
#  u'712': [u'n03920288', u'Petri_dish'],
#  u'711': [u'n03916031', u'perfume'],
#  u'710': [u'n03908714', u'pencil_sharpener'],
#  u'915': [u'n04613696', u'yurt'],
#  u'914': [u'n04612504', u'yawl'],
#  u'606': [u'n03584829', u'iron'],
#  u'917': [u'n06596364', u'comic_book'],
#  u'594': [u'n03495258', u'harp'],
#  u'736': [u'n03982430', u'pool_table'],
#  u'916': [u'n06359193', u'web_site'],
#  u'911': [u'n04599235', u'wool'],
#  u'619': [u'n03637318', u'lampshade'],
#  u'910': [u'n04597913', u'wooden_spoon'],
#  u'913': [u'n04606251', u'wreck'],
#  u'298': [u'n02137549', u'mongoose'],
#  u'299': [u'n02138441', u'meerkat'],
#  u'296': [u'n02134084', u'ice_bear'],
#  u'297': [u'n02134418', u'sloth_bear'],
#  u'294': [u'n02132136', u'brown_bear'],
#  u'295': [u'n02133161', u'American_black_bear'],
#  u'292': [u'n02129604', u'tiger'],
#  u'293': [u'n02130308', u'cheetah'],
#  u'290': [u'n02128925', u'jaguar'],
#  u'291': [u'n02129165', u'lion'],
#  u'591': [u'n03485794', u'handkerchief'],
#  u'590': [u'n03485407', u'hand-held_computer'],
#  u'593': [u'n03494278', u'harmonica'],
#  u'592': [u'n03492542', u'hard_disc'],
#  u'199': [u'n02097298', u'Scotch_terrier'],
#  u'198': [u'n02097209', u'standard_schnauzer'],
#  u'597': [u'n03527444', u'holster'],
#  u'596': [u'n03498962', u'hatchet'],
#  u'195': [u'n02096585', u'Boston_bull'],
#  u'194': [u'n02096437', u'Dandie_Dinmont'],
#  u'197': [u'n02097130', u'giant_schnauzer'],
#  u'196': [u'n02097047', u'miniature_schnauzer'],
#  u'191': [u'n02096051', u'Airedale'],
#  u'190': [u'n02095889', u'Sealyham_terrier'],
#  u'193': [u'n02096294', u'Australian_terrier'],
#  u'192': [u'n02096177', u'cairn'],
#  u'270': [u'n02114548', u'white_wolf'],
#  u'271': [u'n02114712', u'red_wolf'],
#  u'272': [u'n02114855', u'coyote'],
#  u'273': [u'n02115641', u'dingo'],
#  u'274': [u'n02115913', u'dhole'],
#  u'275': [u'n02116738', u'African_hunting_dog'],
#  u'276': [u'n02117135', u'hyena'],
#  u'277': [u'n02119022', u'red_fox'],
#  u'278': [u'n02119789', u'kit_fox'],
#  u'279': [u'n02120079', u'Arctic_fox'],
#  u'738': [u'n03991062', u'pot'],
#  u'524': [u'n03146219', u'cuirass'],
#  u'525': [u'n03160309', u'dam'],
#  u'526': [u'n03179701', u'desk'],
#  u'527': [u'n03180011', u'desktop_computer'],
#  u'520': [u'n03131574', u'crib'],
#  u'521': [u'n03133878', u'Crock_Pot'],
#  u'522': [u'n03134739', u'croquet_ball'],
#  u'523': [u'n03141823', u'crutch'],
#  u'599': [u'n03530642', u'honeycomb'],
#  u'528': [u'n03187595', u'dial_telephone'],
#  u'529': [u'n03188531', u'diaper'],
#  u'994': [u'n13040303', u'stinkhorn'],
#  u'449': [u'n02859443', u'boathouse'],
#  u'448': [u'n02843684', u'birdhouse'],
#  u'443': [u'n02834397', u'bib'],
#  u'442': [u'n02825657', u'bell_cote'],
#  u'441': [u'n02823750', u'beer_glass'],
#  u'440': [u'n02823428', u'beer_bottle'],
#  u'447': [u'n02841315', u'binoculars'],
#  u'446': [u'n02840245', u'binder'],
#  u'445': [u'n02837789', u'bikini'],
#  u'444': [u'n02835271', u'bicycle-built-for-two'],
#  u'108': [u'n01914609', u'sea_anemone'],
#  u'109': [u'n01917289', u'brain_coral'],
#  u'102': [u'n01872401', u'echidna'],
#  u'103': [u'n01873310', u'platypus'],
#  u'100': [u'n01860187', u'black_swan'],
#  u'101': [u'n01871265', u'tusker'],
#  u'106': [u'n01883070', u'wombat'],
#  u'107': [u'n01910747', u'jellyfish'],
#  u'104': [u'n01877812', u'wallaby'],
#  u'105': [u'n01882714', u'koala'],
#  u'902': [u'n04579432', u'whistle'],
#  u'903': [u'n04584207', u'wig'],
#  u'39': [u'n01677366', u'common_iguana'],
#  u'38': [u'n01675722', u'banded_gecko'],
#  u'906': [u'n04591157', u'Windsor_tie'],
#  u'907': [u'n04591713', u'wine_bottle'],
#  u'904': [u'n04589890', u'window_screen'],
#  u'905': [u'n04590129', u'window_shade'],
#  u'33': [u'n01664065', u'loggerhead'],
#  u'32': [u'n01644900', u'tailed_frog'],
#  u'31': [u'n01644373', u'tree_frog'],
#  u'30': [u'n01641577', u'bullfrog'],
#  u'37': [u'n01669191', u'box_turtle'],
#  u'36': [u'n01667778', u'terrapin'],
#  u'35': [u'n01667114', u'mud_turtle'],
#  u'34': [u'n01665541', u'leatherback_turtle'],
#  u'641': [u'n03720891', u'maraca'],
#  u'640': [u'n03717622', u'manhole_cover'],
#  u'643': [u'n03724870', u'mask'],
#  u'642': [u'n03721384', u'marimba'],
#  u'645': [u'n03733131', u'maypole'],
#  u'644': [u'n03729826', u'matchstick'],
#  u'438': [u'n02815834', u'beaker'],
#  u'439': [u'n02817516', u'bearskin'],
#  u'436': [u'n02814533', u'beach_wagon'],
#  u'437': [u'n02814860', u'beacon'],
#  u'434': [u'n02808304', u'bath_towel'],
#  u'435': [u'n02808440', u'bathtub'],
#  u'432': [u'n02804610', u'bassoon'],
#  u'433': [u'n02807133', u'bathing_cap'],
#  u'430': [u'n02802426', u'basketball'],
#  u'431': [u'n02804414', u'bassinet'],
#  u'339': [u'n02389026', u'sorrel'],
#  u'338': [u'n02364673', u'guinea_pig'],
#  u'335': [u'n02356798', u'fox_squirrel'],
#  u'334': [u'n02346627', u'porcupine'],
#  u'337': [u'n02363005', u'beaver'],
#  u'336': [u'n02361337', u'marmot'],
#  u'331': [u'n02326432', u'hare'],
#  u'330': [u'n02325366', u'wood_rabbit'],
#  u'333': [u'n02342885', u'hamster'],
#  u'332': [u'n02328150', u'Angora'],
#  u'744': [u'n04008634', u'projectile'],
#  u'745': [u'n04009552', u'projector'],
#  u'854': [u'n04418357', u'theater_curtain'],
#  u'818': [u'n04286575', u'spotlight'],
#  u'856': [u'n04428191', u'thresher'],
#  u'857': [u'n04429376', u'throne'],
#  u'850': [u'n04399382', u'teddy'],
#  u'851': [u'n04404412', u'television'],
#  u'852': [u'n04409515', u'tennis_ball'],
#  u'345': [u'n02403003', u'ox'],
#  u'858': [u'n04435653', u'tile_roof'],
#  u'859': [u'n04442312', u'toaster'],
#  u'748': [u'n04026417', u'purse'],
#  u'6': [u'n01498041', u'stingray'],
#  u'900': [u'n04562935', u'water_tower'],
#  u'848': [u'n04392985', u'tape_player'],
#  u'99': [u'n01855672', u'goose'],
#  u'98': [u'n01855032', u'red-breasted_merganser'],
#  u'844': [u'n04372370', u'switch'],
#  u'91': [u'n01824575', u'coucal'],
#  u'90': [u'n01820546', u'lorikeet'],
#  u'93': [u'n01829413', u'hornbill'],
#  u'92': [u'n01828970', u'bee_eater'],
#  u'95': [u'n01843065', u'jacamar'],
#  u'94': [u'n01833805', u'hummingbird'],
#  u'97': [u'n01847000', u'drake'],
#  u'96': [u'n01843383', u'toucan'],
#  u'814': [u'n04273569', u'speedboat'],
#  u'815': [u'n04275548', u'spider_web'],
#  u'740': [u'n03995372', u'power_drill'],
#  u'741': [u'n03998194', u'prayer_rug'],
#  u'742': [u'n04004767', u'printer'],
#  u'743': [u'n04005630', u'prison'],
#  u'559': [u'n03376595', u'folding_chair'],
#  u'558': [u'n03372029', u'flute'],
#  u'746': [u'n04019541', u'puck'],
#  u'747': [u'n04023962', u'punching_bag'],
#  u'555': [u'n03345487', u'fire_engine'],
#  u'554': [u'n03344393', u'fireboat'],
#  u'557': [u'n03355925', u'flagpole'],
#  u'556': [u'n03347037', u'fire_screen'],
#  u'551': [u'n03314780', u'face_powder'],
#  u'550': [u'n03297495', u'espresso_maker'],
#  u'553': [u'n03337140', u'file'],
#  u'552': [u'n03325584', u'feather_boa'],
#  u'238': [u'n02107574', u'Greater_Swiss_Mountain_dog'],
#  u'239': [u'n02107683', u'Bernese_mountain_dog'],
#  u'234': [u'n02106550', u'Rottweiler'],
#  u'235': [u'n02106662', u'German_shepherd'],
#  u'236': [u'n02107142', u'Doberman'],
#  u'237': [u'n02107312', u'miniature_pinscher'],
#  u'230': [u'n02105855', u'Shetland_sheepdog'],
#  u'231': [u'n02106030', u'collie'],
#  u'232': [u'n02106166', u'Border_collie'],
#  u'233': [u'n02106382', u'Bouvier_des_Flandres'],
#  u'992': [u'n12998815', u'agaric'],
#  u'1': [u'n01443537', u'goldfish'],
#  u'614': [u'n03617480', u'kimono'],
#  u'146': [u'n02058221', u'albatross'],
#  u'147': [u'n02066245', u'grey_whale'],
#  u'144': [u'n02051845', u'pelican'],
#  u'145': [u'n02056570', u'king_penguin'],
#  u'142': [u'n02033041', u'dowitcher'],
#  u'143': [u'n02037110', u'oystercatcher'],
#  u'140': [u'n02027492', u'red-backed_sandpiper'],
#  u'141': [u'n02028035', u'redshank'],
#  u'612': [u'n03599486', u'jinrikisha'],
#  u'613': [u'n03602883', u'joystick'],
#  u'610': [u'n03595614', u'jersey'],
#  u'611': [u'n03598930', u'jigsaw_puzzle'],
#  u'616': [u'n03627232', u'knot'],
#  u'617': [u'n03630383', u'lab_coat'],
#  u'148': [u'n02071294', u'killer_whale'],
#  u'149': [u'n02074367', u'dugong'],
#  u'912': [u'n04604644', u'worm_fence'],
#  u'951': [u'n07749582', u'lemon'],
#  u'948': [u'n07742313', u'Granny_Smith'],
#  u'949': [u'n07745940', u'strawberry'],
#  u'946': [u'n07730033', u'cardoon'],
#  u'947': [u'n07734744', u'mushroom'],
#  u'944': [u'n07718747', u'artichoke'],
#  u'945': [u'n07720875', u'bell_pepper'],
#  u'942': [u'n07717556', u'butternut_squash'],
#  u'943': [u'n07718472', u'cucumber'],
#  u'940': [u'n07716906', u'spaghetti_squash'],
#  u'941': [u'n07717410', u'acorn_squash'],
#  u'768': [u'n04118538', u'rugby_ball'],
#  u'689': [u'n03866082', u'overskirt'],
#  u'688': [u'n03857828', u'oscilloscope'],
#  u'685': [u'n03841143', u'odometer'],
#  u'684': [u'n03840681', u'ocarina'],
#  u'687': [u'n03854065', u'organ'],
#  u'686': [u'n03843555', u'oil_filter'],
#  u'681': [u'n03832673', u'notebook'],
#  u'680': [u'n03825788', u'nipple'],
#  u'683': [u'n03838899', u'oboe'],
#  u'682': [u'n03837869', u'obelisk'],
#  u'623': [u'n03658185', u'letter_opener'],
#  u'819': [u'n04296562', u'stage'],
#  u'622': [u'n03657121', u'lens_cap'],
#  u'133': [u'n02011460', u'bittern'],
#  u'132': [u'n02009912', u'American_egret'],
#  u'131': [u'n02009229', u'little_blue_heron'],
#  u'130': [u'n02007558', u'flamingo'],
#  u'137': [u'n02018207', u'American_coot'],
#  u'136': [u'n02017213', u'European_gallinule'],
#  u'135': [u'n02013706', u'limpkin'],
#  u'134': [u'n02012849', u'crane'],
#  u'494': [u'n03017168', u'chime'],
#  u'495': [u'n03018349', u'china_cabinet'],
#  u'139': [u'n02025239', u'ruddy_turnstone'],
#  u'138': [u'n02018795', u'bustard'],
#  u'490': [u'n03000247', u'chain_mail'],
#  u'491': [u'n03000684', u'chain_saw'],
#  u'492': [u'n03014705', u'chest'],
#  u'493': [u'n03016953', u'chiffonier'],
#  u'24': [u'n01622779', u'great_grey_owl'],
#  u'25': [u'n01629819', u'European_fire_salamander'],
#  u'26': [u'n01630670', u'common_newt'],
#  u'27': [u'n01631663', u'eft'],
#  u'20': [u'n01601694', u'water_ouzel'],
#  u'21': [u'n01608432', u'kite'],
#  u'22': [u'n01614925', u'bald_eagle'],
#  u'23': [u'n01616318', u'vulture'],
#  u'927': [u'n07613480', u'trifle'],
#  u'28': [u'n01632458', u'spotted_salamander'],
#  u'29': [u'n01632777', u'axolotl'],
#  u'407': [u'n02701002', u'ambulance'],
#  u'406': [u'n02699494', u'altar'],
#  u'405': [u'n02692877', u'airship'],
#  u'404': [u'n02690373', u'airliner'],
#  u'403': [u'n02687172', u'aircraft_carrier'],
#  u'402': [u'n02676566', u'acoustic_guitar'],
#  u'401': [u'n02672831', u'accordion'],
#  u'400': [u'n02669723', u'academic_gown'],
#  u'933': [u'n07697313', u'cheeseburger'],
#  u'932': [u'n07695742', u'pretzel'],
#  u'931': [u'n07693725', u'bagel'],
#  u'930': [u'n07684084', u'French_loaf'],
#  u'937': [u'n07714990', u'broccoli'],
#  u'629': [u'n03676483', u'lipstick'],
#  u'409': [u'n02708093', u'analog_clock'],
#  u'408': [u'n02704792', u'amphibian'],
#  u'628': [u'n03673027', u'liner'],
#  u'758': [u'n04067472', u'reel'],
#  u'379': [u'n02492660', u'howler_monkey'],
#  u'378': [u'n02492035', u'capuchin'],
#  u'829': [u'n04335435', u'streetcar'],
#  u'828': [u'n04332243', u'strainer'],
#  u'371': [u'n02486261', u'patas'],
#  u'370': [u'n02484975', u'guenon'],
#  u'373': [u'n02487347', u'macaque'],
#  u'372': [u'n02486410', u'baboon'],
#  u'375': [u'n02488702', u'colobus'],
#  u'374': [u'n02488291', u'langur'],
#  u'377': [u'n02490219', u'marmoset'],
#  u'376': [u'n02489166', u'proboscis_monkey'],
#  u'708': [u'n03903868', u'pedestal'],
#  u'709': [u'n03908618', u'pencil_box'],
#  u'704': [u'n03891332', u'parking_meter'],
#  u'705': [u'n03895866', u'passenger_car'],
#  u'706': [u'n03899768', u'patio'],
#  u'707': [u'n03902125', u'pay-phone'],
#  u'700': [u'n03887697', u'paper_towel'],
#  u'618': [u'n03633091', u'ladle'],
#  u'702': [u'n03888605', u'parallel_bars'],
#  u'703': [u'n03891251', u'park_bench'],
#  u'393': [u'n02607072', u'anemone_fish'],
#  u'392': [u'n02606052', u'rock_beauty'],
#  u'88': [u'n01818515', u'macaw'],
#  u'89': [u'n01819313', u'sulphur-crested_cockatoo'],
#  u'397': [u'n02655020', u'puffer'],
#  u'396': [u'n02643566', u'lionfish'],
#  u'395': [u'n02641379', u'gar'],
#  u'394': [u'n02640242', u'sturgeon'],
#  u'82': [u'n01797886', u'ruffed_grouse'],
#  u'83': [u'n01798484', u'prairie_chicken'],
#  u'80': [u'n01795545', u'black_grouse'],
#  u'81': [u'n01796340', u'ptarmigan'],
#  u'86': [u'n01807496', u'partridge'],
#  u'87': [u'n01817953', u'African_grey'],
#  u'84': [u'n01806143', u'peacock'],
#  u'85': [u'n01806567', u'quail'],
#  u'797': [u'n04235860', u'sleeping_bag'],
#  u'796': [u'n04229816', u'ski_mask'],
#  u'795': [u'n04228054', u'ski'],
#  u'794': [u'n04209239', u'shower_curtain'],
#  u'793': [u'n04209133', u'shower_cap'],
#  u'792': [u'n04208210', u'shovel'],
#  u'791': [u'n04204347', u'shopping_cart'],
#  u'790': [u'n04204238', u'shopping_basket'],
#  u'799': [u'n04239074', u'sliding_door'],
#  u'798': [u'n04238763', u'slide_rule'],
#  u'7': [u'n01514668', u'cock'],
#  u'601': [u'n03534580', u'hoopskirt'],
#  u'607': [u'n03590841', u"jack-o'-lantern"],
#  u'586': [u'n03478589', u'half_track'],
#  u'587': [u'n03481172', u'hammer'],
#  u'584': [u'n03476684', u'hair_slide'],
#  u'585': [u'n03476991', u'hair_spray'],
#  u'582': [u'n03461385', u'grocery_store'],
#  u'583': [u'n03467068', u'guillotine'],
#  u'580': [u'n03457902', u'greenhouse'],
#  u'581': [u'n03459775', u'grille'],
#  u'588': [u'n03482405', u'hamper'],
#  u'589': [u'n03483316', u'hand_blower'],
#  u'245': [u'n02108915', u'French_bulldog'],
#  u'244': [u'n02108551', u'Tibetan_mastiff'],
#  u'247': [u'n02109525', u'Saint_Bernard'],
#  u'246': [u'n02109047', u'Great_Dane'],
#  u'241': [u'n02108000', u'EntleBucher'],
#  u'240': [u'n02107908', u'Appenzeller'],
#  u'243': [u'n02108422', u'bull_mastiff'],
#  u'242': [u'n02108089', u'boxer'],
#  u'615': [u'n03623198', u'knee_pad'],
#  u'249': [u'n02110063', u'malamute'],
#  u'248': [u'n02109961', u'Eskimo_dog'],
#  u'924': [u'n07583066', u'guacamole'],
#  u'970': [u'n09193705', u'alp'],
#  u'925': [u'n07584110', u'consomme'],
#  u'519': [u'n03127925', u'crate'],
#  u'518': [u'n03127747', u'crash_helmet'],
#  u'926': [u'n07590611', u'hot_pot'],
#  u'511': [u'n03100240', u'convertible'],
#  u'510': [u'n03095699', u'container_ship'],
#  u'513': [u'n03110669', u'cornet'],
#  u'512': [u'n03109150', u'corkscrew'],
#  u'515': [u'n03124170', u'cowboy_hat'],
#  u'514': [u'n03124043', u'cowboy_boot'],
#  u'517': [u'n03126707', u'crane'],
#  u'516': [u'n03125729', u'cradle'],
#  u'458': [u'n02892201', u'brass'],
#  u'459': [u'n02892767', u'brassiere'],
#  u'621': [u'n03649909', u'lawn_mower'],
#  u'620': [u'n03642806', u'laptop'],
#  u'627': [u'n03670208', u'limousine'],
#  u'626': [u'n03666591', u'lighter'],
#  u'625': [u'n03662601', u'lifeboat'],
#  u'624': [u'n03661043', u'library'],
#  u'450': [u'n02860847', u'bobsled'],
#  u'451': [u'n02865351', u'bolo_tie'],
#  u'452': [u'n02869837', u'bonnet'],
#  u'453': [u'n02870880', u'bookcase'],
#  u'454': [u'n02871525', u'bookshop'],
#  u'455': [u'n02877765', u'bottlecap'],
#  u'456': [u'n02879718', u'bow'],
#  u'457': [u'n02883205', u'bow_tie'],
#  u'979': [u'n09468604', u'valley'],
#  u'179': [u'n02093256', u'Staffordshire_bullterrier'],
#  u'178': [u'n02092339', u'Weimaraner'],
#  u'177': [u'n02092002', u'Scottish_deerhound'],
#  u'176': [u'n02091831', u'Saluki'],
#  u'175': [u'n02091635', u'otterhound'],
#  u'174': [u'n02091467', u'Norwegian_elkhound'],
#  u'173': [u'n02091244', u'Ibizan_hound'],
#  u'172': [u'n02091134', u'whippet'],
#  u'171': [u'n02091032', u'Italian_greyhound'],
#  u'170': [u'n02090721', u'Irish_wolfhound'],
#  u'977': [u'n09421951', u'sandbar'],
#  u'656': [u'n03770679', u'minivan'],
#  u'975': [u'n09332890', u'lakeside'],
#  u'974': [u'n09288635', u'geyser'],
#  u'973': [u'n09256479', u'coral_reef'],
#  u'972': [u'n09246464', u'cliff'],
#  u'971': [u'n09229709', u'bubble'],
#  u'657': [u'n03773504', u'missile'],
#  u'654': [u'n03769881', u'minibus'],
#  u'253': [u'n02110806', u'basenji'],
#  u'978': [u'n09428293', u'seashore'],
#  u'182': [u'n02093754', u'Border_terrier'],
#  u'183': [u'n02093859', u'Kerry_blue_terrier'],
#  u'180': [u'n02093428', u'American_Staffordshire_terrier'],
#  u'181': [u'n02093647', u'Bedlington_terrier'],
#  u'186': [u'n02094258', u'Norwich_terrier'],
#  u'187': [u'n02094433', u'Yorkshire_terrier'],
#  u'184': [u'n02093991', u'Irish_terrier'],
#  u'185': [u'n02094114', u'Norfolk_terrier'],
#  u'886': [u'n04525305', u'vending_machine'],
#  u'652': [u'n03763968', u'military_uniform'],
#  u'188': [u'n02095314', u'wire-haired_fox_terrier'],
#  u'189': [u'n02095570', u'Lakeland_terrier'],
#  u'658': [u'n03775071', u'mitten'],
#  u'653': [u'n03764736', u'milk_can'],
#  u'650': [u'n03759954', u'microphone'],
#  u'651': [u'n03761084', u'microwave'],
#  u'764': [u'n04090263', u'rifle'],
#  u'11': [u'n01531178', u'goldfinch'],
#  u'10': [u'n01530575', u'brambling'],
#  u'13': [u'n01534433', u'junco'],
#  u'12': [u'n01532829', u'house_finch'],
#  u'15': [u'n01558993', u'robin'],
#  u'14': [u'n01537544', u'indigo_bunting'],
#  u'17': [u'n01580077', u'jay'],
#  u'16': [u'n01560419', u'bulbul'],
#  u'19': [u'n01592084', u'chickadee'],
#  u'18': [u'n01582220', u'magpie'],
#  u'863': [u'n04458633', u'totem_pole'],
#  u'862': [u'n04456115', u'torch'],
#  u'865': [u'n04462240', u'toyshop'],
#  u'864': [u'n04461696', u'tow_truck'],
#  u'867': [u'n04467665', u'trailer_truck'],
#  u'866': [u'n04465501', u'tractor'],
#  u'884': [u'n04523525', u'vault'],
#  u'938': [u'n07715103', u'cauliflower'],
#  u'659': [u'n03775546', u'mixing_bowl'],
#  u'883': [u'n04522168', u'vase'],
#  u'753': [u'n04040759', u'radiator'],
#  u'881': [u'n04515003', u'upright'],
#  u'880': [u'n04509417', u'unicycle'],
#  u'887': [u'n04532106', u'vestment'],
#  u'831': [u'n04344873', u'studio_couch'],
#  u'885': [u'n04525038', u'velvet'],
#  u'752': [u'n04039381', u'racket'],
#  u'928': [u'n07614500', u'ice_cream'],
#  u'62': [u'n01744401', u'rock_python'],
#  u'888': [u'n04532670', u'viaduct'],
#  u'950': [u'n07747607', u'orange'],
#  u'756': [u'n04049303', u'rain_barrel'],
#  u'929': [u'n07615774', u'ice_lolly'],
#  u'809': [u'n04263257', u'soup_bowl'],
#  u'322': [u'n02277742', u'ringlet'],
#  u'323': [u'n02279972', u'monarch'],
#  u'320': [u'n02268853', u'damselfly'],
#  u'321': [u'n02276258', u'admiral'],
#  u'326': [u'n02281787', u'lycaenid'],
#  u'327': [u'n02317335', u'starfish'],
#  u'324': [u'n02280649', u'cabbage_butterfly'],
#  u'325': [u'n02281406', u'sulphur_butterfly'],
#  u'328': [u'n02319095', u'sea_urchin'],
#  u'329': [u'n02321529', u'sea_cucumber'],
#  u'759': [u'n04069434', u'reflex_camera'],
#  u'201': [u'n02097658', u'silky_terrier'],
#  u'200': [u'n02097474', u'Tibetan_terrier'],
#  u'203': [u'n02098286', u'West_Highland_white_terrier'],
#  u'202': [u'n02098105', u'soft-coated_wheaten_terrier'],
#  u'205': [u'n02099267', u'flat-coated_retriever'],
#  u'204': [u'n02098413', u'Lhasa'],
#  u'207': [u'n02099601', u'golden_retriever'],
#  u'206': [u'n02099429', u'curly-coated_retriever'],
#  u'209': [u'n02099849', u'Chesapeake_Bay_retriever'],
#  u'208': [u'n02099712', u'Labrador_retriever'],
#  u'779': [u'n04146614', u'school_bus'],
#  u'778': [u'n04141975', u'scale'],
#  u'889': [u'n04536866', u'violin'],
#  u'77': [u'n01775062', u'wolf_spider'],
#  u'76': [u'n01774750', u'tarantula'],
#  u'75': [u'n01774384', u'black_widow'],
#  u'74': [u'n01773797', u'garden_spider'],
#  u'73': [u'n01773549', u'barn_spider'],
#  u'72': [u'n01773157', u'black_and_gold_garden_spider'],
#  u'71': [u'n01770393', u'scorpion'],
#  u'70': [u'n01770081', u'harvestman'],
#  u'655': [u'n03770439', u'miniskirt'],
#  u'79': [u'n01784675', u'centipede'],
#  u'78': [u'n01776313', u'tick'],
#  u'2': [u'n01484850', u'great_white_shark'],
#  u'805': [u'n04254680', u'soccer_ball'],
#  u'804': [u'n04254120', u'soap_dispenser'],
#  u'669': [u'n03788365', u'mosquito_net'],
#  u'668': [u'n03788195', u'mosque'],
#  u'667': [u'n03787032', u'mortarboard'],
#  u'666': [u'n03786901', u'mortar'],
#  u'665': [u'n03785016', u'moped'],
#  u'664': [u'n03782006', u'monitor'],
#  u'663': [u'n03781244', u'monastery'],
#  u'662': [u'n03777754', u'modem'],
#  u'661': [u'n03777568', u'Model_T'],
#  u'660': [u'n03776460', u'mobile_home'],
#  u'769': [u'n04118776', u'rule'],
#  u'692': [u'n03871628', u'packet'],
#  u'693': [u'n03873416', u'paddle'],
#  u'690': [u'n03868242', u'oxcart'],
#  u'691': [u'n03868863', u'oxygen_mask'],
#  u'696': [u'n03876231', u'paintbrush'],
#  u'697': [u'n03877472', u'pajama'],
#  u'694': [u'n03874293', u'paddlewheel'],
#  u'695': [u'n03874599', u'padlock'],
#  u'698': [u'n03877845', u'palace'],
#  u'699': [u'n03884397', u'panpipe'],
#  u'542': [u'n03250847', u'drumstick'],
#  u'543': [u'n03255030', u'dumbbell'],
#  u'540': [u'n03240683', u'drilling_platform'],
#  u'541': [u'n03249569', u'drum'],
#  u'546': [u'n03272010', u'electric_guitar'],
#  u'547': [u'n03272562', u'electric_locomotive'],
#  u'544': [u'n03259280', u'Dutch_oven'],
#  u'545': [u'n03271574', u'electric_fan'],
#  u'8': [u'n01514859', u'hen'],
#  u'548': [u'n03290653', u'entertainment_center'],
#  u'549': [u'n03291819', u'envelope'],
#  u'68': [u'n01756291', u'sidewinder'],
#  u'598': [u'n03529860', u'home_theater'],
#  u'995': [u'n13044778', u'earthstar'],
#  u'869': [u'n04479046', u'trench_coat'],
#  u'997': [u'n13054560', u'bolete'],
#  u'996': [u'n13052670', u'hen-of-the-woods'],
#  u'991': [u'n12985857', u'coral_fungus'],
#  u'990': [u'n12768682', u'buckeye'],
#  u'993': [u'n13037406', u'gyromitra'],
#  u'868': [u'n04476259', u'tray'],
#  u'999': [u'n15075141', u'toilet_tissue'],
#  u'998': [u'n13133613', u'ear'],
#  u'120': [u'n01980166', u'fiddler_crab'],
#  u'121': [u'n01981276', u'king_crab'],
#  u'122': [u'n01983481', u'American_lobster'],
#  u'123': [u'n01984695', u'spiny_lobster'],
#  u'124': [u'n01985128', u'crayfish'],
#  u'125': [u'n01986214', u'hermit_crab'],
#  u'126': [u'n01990800', u'isopod'],
#  u'127': [u'n02002556', u'white_stork'],
#  u'128': [u'n02002724', u'black_stork'],
#  u'129': [u'n02006656', u'spoonbill'],
#  u'765': [u'n04099969', u'rocking_chair'],
#  u'414': [u'n02769748', u'backpack'],
#  u'415': [u'n02776631', u'bakery'],
#  u'416': [u'n02777292', u'balance_beam'],
#  u'417': [u'n02782093', u'balloon'],
#  u'410': [u'n02727426', u'apiary'],
#  u'411': [u'n02730930', u'apron'],
#  u'412': [u'n02747177', u'ashcan'],
#  u'413': [u'n02749479', u'assault_rifle'],
#  u'920': [u'n06874185', u'traffic_light'],
#  u'498': [u'n03032252', u'cinema'],
#  u'922': [u'n07565083', u'menu'],
#  u'923': [u'n07579787', u'plate'],
#  u'418': [u'n02783161', u'ballpoint'],
#  u'419': [u'n02786058', u'Band_Aid'],
#  u'776': [u'n04141076', u'sax'],
#  u'499': [u'n03041632', u'cleaver'],
#  u'319': [u'n02268443', u'dragonfly'],
#  u'318': [u'n02264363', u'lacewing'],
#  u'313': [u'n02231487', u'walking_stick'],
#  u'312': [u'n02229544', u'cricket'],
#  u'311': [u'n02226429', u'grasshopper'],
#  u'310': [u'n02219486', u'ant'],
#  u'317': [u'n02259212', u'leafhopper'],
#  u'316': [u'n02256656', u'cicada'],
#  u'315': [u'n02236044', u'mantis'],
#  u'314': [u'n02233338', u'cockroach'],
#  u'861': [u'n04447861', u'toilet_seat'],
#  u'921': [u'n07248320', u'book_jacket'],
#  u'496': [u'n03026506', u'Christmas_stocking'],
#  u'832': [u'n04346328', u'stupa'],
#  u'833': [u'n04347754', u'submarine'],
#  u'830': [u'n04336792', u'stretcher'],
#  u'497': [u'n03028079', u'church'],
#  u'836': [u'n04355933', u'sunglass'],
#  u'837': [u'n04356056', u'sunglasses'],
#  u'834': [u'n04350905', u'suit'],
#  u'835': [u'n04355338', u'sundial'],
#  u'838': [u'n04357314', u'sunscreen'],
#  u'839': [u'n04366367', u'suspension_bridge'],
#  u'808': [u'n04259630', u'sombrero'],
#  u'3': [u'n01491361', u'tiger_shark'],
#  u'725': [u'n03950228', u'pitcher'],
#  u'368': [u'n02483362', u'gibbon'],
#  u'369': [u'n02483708', u'siamang'],
#  u'366': [u'n02480855', u'gorilla'],
#  u'367': [u'n02481823', u'chimpanzee'],
#  u'364': [u'n02457408', u'three-toed_sloth'],
#  u'365': [u'n02480495', u'orangutan'],
#  u'362': [u'n02447366', u'badger'],
#  u'363': [u'n02454379', u'armadillo'],
#  u'360': [u'n02444819', u'otter'],
#  u'361': [u'n02445715', u'skunk'],
#  u'959': [u'n07831146', u'carbonara'],
#  u'952': [u'n07753113', u'fig'],
#  u'882': [u'n04517823', u'vacuum'],
#  u'380': [u'n02493509', u'titi'],
#  u'381': [u'n02493793', u'spider_monkey'],
#  u'382': [u'n02494079', u'squirrel_monkey'],
#  u'383': [u'n02497673', u'Madagascar_cat'],
#  u'384': [u'n02500267', u'indri'],
#  u'385': [u'n02504013', u'Indian_elephant'],
#  u'386': [u'n02504458', u'African_elephant'],
#  u'387': [u'n02509815', u'lesser_panda'],
#  u'388': [u'n02510455', u'giant_panda'],
#  u'389': [u'n02514041', u'barracouta'],
#  u'784': [u'n04154565', u'screwdriver'],
#  u'785': [u'n04162706', u'seat_belt'],
#  u'786': [u'n04179913', u'sewing_machine'],
#  u'787': [u'n04192698', u'shield'],
#  u'780': [u'n04147183', u'schooner'],
#  u'781': [u'n04149813', u'scoreboard'],
#  u'782': [u'n04152593', u'screen'],
#  u'783': [u'n04153751', u'screw'],
#  u'788': [u'n04200800', u'shoe_shop'],
#  u'789': [u'n04201297', u'shoji'],
#  u'860': [u'n04443257', u'tobacco_shop'],
#  u'605': [u'n03584254', u'iPod'],
#  u'579': [u'n03452741', u'grand_piano'],
#  u'578': [u'n03450230', u'gown'],
#  u'604': [u'n03544143', u'hourglass'],
#  u'573': [u'n03444034', u'go-kart'],
#  u'572': [u'n03443371', u'goblet'],
#  u'571': [u'n03425413', u'gas_pump'],
#  u'570': [u'n03424325', u'gasmask'],
#  u'577': [u'n03447721', u'gong'],
#  u'576': [u'n03447447', u'gondola'],
#  u'575': [u'n03445924', u'golfcart'],
#  u'574': [u'n03445777', u'golf_ball'],
#  u'60': [u'n01740131', u'night_snake'],
#  u'61': [u'n01742172', u'boa_constrictor'],
#  u'258': [u'n02111889', u'Samoyed'],
#  u'259': [u'n02112018', u'Pomeranian'],
#  u'64': [u'n01749939', u'green_mamba'],
#  u'65': [u'n01751748', u'sea_snake'],
#  u'66': [u'n01753488', u'horned_viper'],
#  u'67': [u'n01755581', u'diamondback'],
#  u'252': [u'n02110627', u'affenpinscher'],
#  u'69': [u'n01768244', u'trilobite'],
#  u'250': [u'n02110185', u'Siberian_husky'],
#  u'251': [u'n02110341', u'dalmatian'],
#  u'256': [u'n02111277', u'Newfoundland'],
#  u'257': [u'n02111500', u'Great_Pyrenees'],
#  u'254': [u'n02110958', u'pug'],
#  u'255': [u'n02111129', u'Leonberg'],
#  u'603': [u'n03538406', u'horse_cart'],
#  u'602': [u'n03535780', u'horizontal_bar'],
#  u'939': [u'n07716358', u'zucchini'],
#  u'731': [u'n03970156', u'plunger'],
#  u'730': [u'n03967562', u'plow'],
#  u'733': [u'n03976657', u'pole'],
#  u'732': [u'n03976467', u'Polaroid_camera'],
#  u'735': [u'n03980874', u'poncho'],
#  u'734': [u'n03977966', u'police_van'],
#  u'508': [u'n03085013', u'computer_keyboard'],
#  u'509': [u'n03089624', u'confectionery'],
#  u'506': [u'n03065424', u'coil'],
#  u'507': [u'n03075370', u'combination_lock'],
#  u'504': [u'n03063599', u'coffee_mug'],
#  u'505': [u'n03063689', u'coffeepot'],
#  u'502': [u'n03047690', u'clog'],
#  u'503': [u'n03062245', u'cocktail_shaker'],
#  u'500': [u'n03042490', u'cliff_dwelling'],
#  u'501': [u'n03045698', u'cloak'],
#  u'630': [u'n03680355', u'Loafer'],
#  u'631': [u'n03690938', u'lotion'],
#  u'632': [u'n03691459', u'loudspeaker'],
#  u'633': [u'n03692522', u'loupe'],
#  u'469': [u'n02939185', u'caldron'],
#  u'468': [u'n02930766', u'cab'],
#  u'636': [u'n03709823', u'mailbag'],
#  u'637': [u'n03710193', u'mailbox'],
#  u'465': [u'n02916936', u'bulletproof_vest'],
#  u'464': [u'n02910353', u'buckle'],
#  u'467': [u'n02927161', u'butcher_shop'],
#  u'466': [u'n02917067', u'bullet_train'],
#  u'461': [u'n02895154', u'breastplate'],
#  u'460': [u'n02894605', u'breakwater'],
#  u'463': [u'n02909870', u'bucket'],
#  u'462': [u'n02906734', u'broom'],
#  u'901': [u'n04579145', u'whiskey_jug'],
#  u'168': [u'n02090379', u'redbone'],
#  u'169': [u'n02090622', u'borzoi'],
#  u'164': [u'n02088632', u'bluetick'],
#  u'165': [u'n02089078', u'black-and-tan_coonhound'],
#  u'166': [u'n02089867', u'Walker_hound'],
#  u'167': [u'n02089973', u'English_foxhound'],
#  u'160': [u'n02088094', u'Afghan_hound'],
#  u'161': [u'n02088238', u'basset'],
#  u'162': [u'n02088364', u'beagle'],
#  u'163': [u'n02088466', u'bloodhound'],
#  u'964': [u'n07875152', u'potpie'],
#  u'965': [u'n07880968', u'burrito'],
#  u'966': [u'n07892512', u'red_wine'],
#  u'967': [u'n07920052', u'espresso'],
#  u'960': [u'n07836838', u'chocolate_sauce'],
#  u'961': [u'n07860988', u'dough'],
#  u'962': [u'n07871810', u'meat_loaf'],
#  u'963': [u'n07873807', u'pizza'],
#  u'968': [u'n07930864', u'cup'],
#  u'969': [u'n07932039', u'eggnog'],
#  u'936': [u'n07714571', u'head_cabbage'],
#  u'935': [u'n07711569', u'mashed_potato'],
#  u'934': [u'n07697537', u'hotdog'],
#  u'908': [u'n04592741', u'wing'],
#  u'909': [u'n04596742', u'wok'],
#  u'600': [u'n03532672', u'hook'],
#  u'878': [u'n04505470', u'typewriter_keyboard'],
#  u'879': [u'n04507155', u'umbrella'],
#  u'876': [u'n04493381', u'tub'],
#  u'877': [u'n04501370', u'turnstile'],
#  u'874': [u'n04487081', u'trolleybus'],
#  u'875': [u'n04487394', u'trombone'],
#  u'872': [u'n04485082', u'tripod'],
#  u'873': [u'n04486054', u'triumphal_arch'],
#  u'870': [u'n04482393', u'tricycle'],
#  u'871': [u'n04483307', u'trimaran'],
#  u'9': [u'n01518878', u'ostrich'],
#  u'890': [u'n04540053', u'volleyball'],
#  u'891': [u'n04542943', u'waffle_iron'],
#  u'892': [u'n04548280', u'wall_clock'],
#  u'893': [u'n04548362', u'wallet'],
#  u'894': [u'n04550184', u'wardrobe'],
#  u'647': [u'n03733805', u'measuring_cup'],
#  u'896': [u'n04553703', u'washbasin'],
#  u'897': [u'n04554684', u'washer'],
#  u'898': [u'n04557648', u'water_bottle'],
#  u'899': [u'n04560804', u'water_jug'],
#  u'646': [u'n03733281', u'maze'],
#  u'649': [u'n03743016', u'megalith'],
#  u'648': [u'n03742115', u'medicine_chest'],
#  u'357': [u'n02442845', u'mink'],
#  u'356': [u'n02441942', u'weasel'],
#  u'355': [u'n02437616', u'llama'],
#  u'354': [u'n02437312', u'Arabian_camel'],
#  u'353': [u'n02423022', u'gazelle'],
#  u'352': [u'n02422699', u'impala'],
#  u'351': [u'n02422106', u'hartebeest'],
#  u'350': [u'n02417914', u'ibex'],
#  u'803': [u'n04252225', u'snowplow'],
#  u'802': [u'n04252077', u'snowmobile'],
#  u'801': [u'n04251144', u'snorkel'],
#  u'800': [u'n04243546', u'slot'],
#  u'807': [u'n04258138', u'solar_dish'],
#  u'806': [u'n04254777', u'sock'],
#  u'359': [u'n02443484', u'black-footed_ferret'],
#  u'358': [u'n02443114', u'polecat'],
#  u'216': [u'n02101556', u'clumber'],
#  u'217': [u'n02102040', u'English_springer'],
#  u'214': [u'n02101006', u'Gordon_setter'],
#  u'215': [u'n02101388', u'Brittany_spaniel'],
#  u'212': [u'n02100735', u'English_setter'],
#  u'213': [u'n02100877', u'Irish_setter'],
#  u'210': [u'n02100236', u'German_short-haired_pointer'],
#  u'211': [u'n02100583', u'vizsla'],
#  u'762': [u'n04081281', u'restaurant'],
#  u'763': [u'n04086273', u'revolver'],
#  u'760': [u'n04070727', u'refrigerator'],
#  u'761': [u'n04074963', u'remote_control'],
#  u'766': [u'n04111531', u'rotisserie'],
#  u'767': [u'n04116512', u'rubber_eraser'],
#  u'218': [u'n02102177', u'Welsh_springer_spaniel'],
#  u'219': [u'n02102318', u'cocker_spaniel'],
#  u'957': [u'n07768694', u'pomegranate'],
#  u'956': [u'n07760859', u'custard_apple'],
#  u'289': [u'n02128757', u'snow_leopard'],
#  u'288': [u'n02128385', u'leopard'],
#  u'4': [u'n01494475', u'hammerhead'],
#  u'281': [u'n02123045', u'tabby'],
#  u'280': [u'n02120505', u'grey_fox'],
#  u'283': [u'n02123394', u'Persian_cat'],
#  u'282': [u'n02123159', u'tiger_cat'],
#  u'285': [u'n02124075', u'Egyptian_cat'],
#  u'284': [u'n02123597', u'Siamese_cat'],
#  u'287': [u'n02127052', u'lynx'],
#  u'286': [u'n02125311', u'cougar'],
#  u'678': [u'n03814639', u'neck_brace'],
#  u'679': [u'n03814906', u'necklace'],
#  u'674': [u'n03794056', u'mousetrap'],
#  u'675': [u'n03796401', u'moving_van'],
#  u'676': [u'n03803284', u'muzzle'],
#  u'677': [u'n03804744', u'nail'],
#  u'670': [u'n03791053', u'motor_scooter'],
#  u'671': [u'n03792782', u'mountain_bike'],
#  u'672': [u'n03792972', u'mountain_tent'],
#  u'673': [u'n03793489', u'mouse'],
#  u'263': [u'n02113023', u'Pembroke'],
#  u'262': [u'n02112706', u'Brabancon_griffon'],
#  u'261': [u'n02112350', u'keeshond'],
#  u'260': [u'n02112137', u'chow'],
#  u'267': [u'n02113799', u'standard_poodle'],
#  u'266': [u'n02113712', u'miniature_poodle'],
#  u'265': [u'n02113624', u'toy_poodle'],
#  u'264': [u'n02113186', u'Cardigan'],
#  u'269': [u'n02114367', u'timber_wolf'],
#  u'268': [u'n02113978', u'Mexican_hairless'],
#  u'701': [u'n03888257', u'parachute'],
#  u'59': [u'n01739381', u'vine_snake'],
#  u'58': [u'n01737021', u'water_snake'],
#  u'55': [u'n01729977', u'green_snake'],
#  u'54': [u'n01729322', u'hognose_snake'],
#  u'57': [u'n01735189', u'garter_snake'],
#  u'56': [u'n01734418', u'king_snake'],
#  u'51': [u'n01704323', u'triceratops'],
#  u'50': [u'n01698640', u'American_alligator'],
#  u'53': [u'n01728920', u'ringneck_snake'],
#  u'52': [u'n01728572', u'thunder_snake'],
#  u'537': [u'n03218198', u'dogsled'],
#  u'536': [u'n03216828', u'dock'],
#  u'535': [u'n03208938', u'disk_brake'],
#  u'63': [u'n01748264', u'Indian_cobra'],
#  u'533': [u'n03207743', u'dishrag'],
#  u'532': [u'n03201208', u'dining_table'],
#  u'531': [u'n03197337', u'digital_watch'],
#  u'530': [u'n03196217', u'digital_clock'],
#  u'539': [u'n03223299', u'doormat'],
#  u'538': [u'n03220513', u'dome'],
#  u'987': [u'n12144580', u'corn'],
#  u'775': [u'n04136333', u'sarong'],
#  u'988': [u'n12267677', u'acorn'],
#  u'989': [u'n12620546', u'hip'],
#  u'774': [u'n04133789', u'sandal'],
#  u'982': [u'n10148035', u'groom'],
#  u'983': [u'n10565667', u'scuba_diver'],
#  u'980': [u'n09472597', u'volcano'],
#  u'981': [u'n09835506', u'ballplayer'],
#  u'986': [u'n12057211', u"yellow_lady's_slipper"],
#  u'777': [u'n04141327', u'scabbard'],
#  u'984': [u'n11879895', u'rapeseed'],
#  u'985': [u'n11939491', u'daisy'],
#  u'115': [u'n01950731', u'sea_slug'],
#  u'114': [u'n01945685', u'slug'],
#  u'117': [u'n01968897', u'chambered_nautilus'],
#  u'116': [u'n01955084', u'chiton'],
#  u'111': [u'n01930112', u'nematode'],
#  u'110': [u'n01924916', u'flatworm'],
#  u'113': [u'n01944390', u'snail'],
#  u'112': [u'n01943899', u'conch'],
#  u'771': [u'n04125021', u'safe'],
#  u'119': [u'n01978455', u'rock_crab'],
#  u'118': [u'n01978287', u'Dungeness_crab'],
#  u'770': [u'n04120489', u'running_shoe'],
#  u'773': [u'n04131690', u'saltshaker'],
#  u'772': [u'n04127249', u'safety_pin'],
#  u'953': [u'n07753275', u'pineapple'],
#  u'429': [u'n02799071', u'baseball'],
#  u'428': [u'n02797295', u'barrow'],
#  u'534': [u'n03207941', u'dishwasher'],
#  u'919': [u'n06794110', u'street_sign'],
#  u'918': [u'n06785654', u'crossword_puzzle'],
#  u'421': [u'n02788148', u'bannister'],
#  u'420': [u'n02787622', u'banjo'],
#  u'423': [u'n02791124', u'barber_chair'],
#  u'422': [u'n02790996', u'barbell'],
#  u'425': [u'n02793495', u'barn'],
#  u'424': [u'n02791270', u'barbershop'],
#  u'427': [u'n02795169', u'barrel'],
#  u'426': [u'n02794156', u'barometer'],
#  u'308': [u'n02190166', u'fly'],
#  u'309': [u'n02206856', u'bee'],
#  u'855': [u'n04423845', u'thimble'],
#  u'300': [u'n02165105', u'tiger_beetle'],
#  u'301': [u'n02165456', u'ladybug'],
#  u'302': [u'n02167151', u'ground_beetle'],
#  u'303': [u'n02168699', u'long-horned_beetle'],
#  u'304': [u'n02169497', u'leaf_beetle'],
#  u'305': [u'n02172182', u'dung_beetle'],
#  u'306': [u'n02174001', u'rhinoceros_beetle'],
#  u'307': [u'n02177972', u'weevil'],
#  u'895': [u'n04552348', u'warplane'],
#  u'825': [u'n04326547', u'stone_wall'],
#  u'824': [u'n04325704', u'stole'],
#  u'827': [u'n04330267', u'stove'],
#  u'847': [u'n04389033', u'tank'],
#  u'846': [u'n04380533', u'table_lamp'],
#  u'845': [u'n04376876', u'syringe'],
#  u'826': [u'n04328186', u'stopwatch'],
#  u'843': [u'n04371774', u'swing'],
#  u'842': [u'n04371430', u'swimming_trunks'],
#  u'841': [u'n04370456', u'sweatshirt'],
#  u'840': [u'n04367480', u'swab'],
#  u'821': [u'n04311004', u'steel_arch_bridge'],
#  u'853': [u'n04417672', u'thatch'],
#  u'849': [u'n04398044', u'teapot'],
#  u'820': [u'n04310018', u'steam_locomotive'],
#  u'823': [u'n04317175', u'stethoscope'],
#  u'822': [u'n04311174', u'steel_drum'],
#  u'954': [u'n07753592', u'banana'],
#  u'568': [u'n03404251', u'fur_coat'],
#  u'569': [u'n03417042', u'garbage_truck'],
#  u'751': [u'n04037443', u'racer'],
#  u'750': [u'n04033995', u'quilt'],
#  u'757': [u'n04065272', u'recreational_vehicle'],
#  u'737': [u'n03983396', u'pop_bottle'],
#  u'755': [u'n04044716', u'radio_telescope'],
#  u'754': [u'n04041544', u'radio'],
#  u'560': [u'n03379051', u'football_helmet'],
#  u'561': [u'n03384352', u'forklift'],
#  u'562': [u'n03388043', u'fountain'],
#  u'563': [u'n03388183', u'fountain_pen'],
#  u'564': [u'n03388549', u'four-poster'],
#  u'565': [u'n03393912', u'freight_car'],
#  u'566': [u'n03394916', u'French_horn'],
#  u'567': [u'n03400231', u'frying_pan'],
#  u'739': [u'n03992509', u"potter's_wheel"],
#  u'229': [u'n02105641', u'Old_English_sheepdog'],
#  u'228': [u'n02105505', u'komondor'],
#  u'227': [u'n02105412', u'kelpie'],
#  u'226': [u'n02105251', u'briard'],
#  u'225': [u'n02105162', u'malinois'],
#  u'224': [u'n02105056', u'groenendael'],
#  u'223': [u'n02104365', u'schipperke'],
#  u'222': [u'n02104029', u'kuvasz'],
#  u'221': [u'n02102973', u'Irish_water_spaniel'],
#  u'220': [u'n02102480', u'Sussex_spaniel'],
#  u'391': [u'n02536864', u'coho'],
#  u'726': [u'n03954731', u'plane'],
#  u'727': [u'n03956157', u'planetarium'],
#  u'724': [u'n03947888', u'pirate'],
#  u'390': [u'n02526121', u'eel'],
#  u'722': [u'n03942813', u'ping-pong_ball'],
#  u'723': [u'n03944341', u'pinwheel'],
#  u'720': [u'n03937543', u'pill_bottle'],
#  u'721': [u'n03938244', u'pillow'],
#  u'728': [u'n03958227', u'plastic_bag'],
#  u'729': [u'n03961711', u'plate_rack'],
#  u'151': [u'n02085620', u'Chihuahua'],
#  u'150': [u'n02077923', u'sea_lion'],
#  u'153': [u'n02085936', u'Maltese_dog'],
#  u'152': [u'n02085782', u'Japanese_spaniel'],
#  u'155': [u'n02086240', u'Shih-Tzu'],
#  u'154': [u'n02086079', u'Pekinese'],
#  u'157': [u'n02086910', u'papillon'],
#  u'156': [u'n02086646', u'Blenheim_spaniel'],
#  u'159': [u'n02087394', u'Rhodesian_ridgeback'],
#  u'158': [u'n02087046', u'toy_terrier'],
#  u'609': [u'n03594945', u'jeep'],
#  u'608': [u'n03594734', u'jean'],
#  u'976': [u'n09399592', u'promontory'],
#  u'634': [u'n03697007', u'lumbermill'],
#  u'399': [u'n02667093', u'abaya'],
#  u'635': [u'n03706229', u'magnetic_compass'],
#  u'749': [u'n04033901', u'quill'],
#  u'958': [u'n07802026', u'hay'],
#  u'398': [u'n02666196', u'abacus'],
#  u'48': [u'n01695060', u'Komodo_dragon'],
#  u'49': [u'n01697457', u'African_crocodile'],
#  u'46': [u'n01693334', u'green_lizard'],
#  u'47': [u'n01694178', u'African_chameleon'],
#  u'44': [u'n01689811', u'alligator_lizard'],
#  u'45': [u'n01692333', u'Gila_monster'],
#  u'42': [u'n01687978', u'agama'],
#  u'43': [u'n01688243', u'frilled_lizard'],
#  u'40': [u'n01682714', u'American_chameleon'],
#  u'41': [u'n01685808', u'whiptail'],
#  u'638': [u'n03710637', u'maillot'],
#  u'5': [u'n01496331', u'electric_ray'],
#  u'639': [u'n03710721', u'maillot'],
#  u'489': [u'n03000134', u'chainlink_fence'],
#  u'488': [u'n02999410', u'chain'],
#  u'487': [u'n02992529', u'cellular_telephone'],
#  u'486': [u'n02992211', u'cello'],
#  u'485': [u'n02988304', u'CD_player'],
#  u'484': [u'n02981792', u'catamaran'],
#  u'483': [u'n02980441', u'castle'],
#  u'482': [u'n02979186', u'cassette_player'],
#  u'481': [u'n02978881', u'cassette'],
#  u'480': [u'n02977058', u'cash_machine'],
#  u'955': [u'n07754684', u'jackfruit'],
#  u'472': [u'n02951358', u'canoe'],
#  u'473': [u'n02951585', u'can_opener'],
#  u'470': [u'n02948072', u'candle'],
#  u'471': [u'n02950826', u'cannon'],
#  u'476': [u'n02966193', u'carousel'],
#  u'477': [u'n02966687', u"carpenter's_kit"],
#  u'474': [u'n02963159', u'cardigan'],
#  u'475': [u'n02965783', u'car_mirror'],
#  u'478': [u'n02971356', u'carton'],
#  u'479': [u'n02974003', u'car_wheel']}

# %% [markdown]
# ## Model creation
#
# Creating the model involves creating the model architecture, and then loading the model weights into that architecture. We will start by defining the basic pieces of the VGG architecture.
#
# VGG has just one type of convolutional block, and one type of fully connected ('dense') block. Here's the convolutional block definition:

# %%
def ConvBlock(layers, model, filters):
    for i in range(layers): 
        model.add(ZeroPadding2D((1,1)))
        model.add(Convolution2D(filters, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

# %% [markdown]
# ...and here's the fully-connected definition.

# %%
def FCBlock(model):
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))

# %% [markdown]
# When the VGG model was trained in 2014, the creators subtracted the average of each of the three (R,G,B) channels first, so that the data for each channel had a mean of zero. Furthermore, their software that expected the channels to be in B,G,R order, whereas Python by default uses R,G,B. We need to preprocess our data to make these two changes, so that it is compatible with the VGG model:

# %%
# Mean of each channel as provided by VGG researchers
vgg_mean = np.array([123.68, 116.779, 103.939]).reshape((3,1,1))

def vgg_preprocess(x):
    x = x - vgg_mean     # subtract mean
    return x[:, ::-1]    # reverse axis bgr->rgb

# %%
vgg_mean
# Out:
# array([[[ 123.68 ]],
#
#        [[ 116.779]],
#
#        [[ 103.939]]])

# %% [markdown]
# Now we're ready to define the VGG model architecture - look at how simple it is, now that we have the basic blocks defined!

# %%
def VGG_16():
    model = Sequential()
    model.add(Lambda(vgg_preprocess, input_shape=(3,224,224)))

    ConvBlock(2, model, 64)
    ConvBlock(2, model, 128)
    ConvBlock(3, model, 256)
    ConvBlock(3, model, 512)
    ConvBlock(3, model, 512)

    model.add(Flatten())
    FCBlock(model)
    FCBlock(model)
    model.add(Dense(1000, activation='softmax'))
    return model

# %% [markdown]
# We'll learn about what these different blocks do later in the course. For now, it's enough to know that:
#
# - Convolution layers are for finding patterns in images
# - Dense (fully connected) layers are for combining patterns across an image
#
# Now that we've defined the architecture, we can create the model like any python object:

# %%
model = VGG_16()

# %% [markdown]
# As well as the architecture, we need the weights that the VGG creators trained. The weights are the part of the model that is learnt from the data, whereas the architecture is pre-defined based on the nature of the problem.
#
# Downloading pre-trained weights is much preferred to training the model ourselves, since otherwise we would have to download the entire Imagenet archive, and train the model for many days! It's very helpful when researchers release their weights, as they did here.

# %%
fpath = get_file('vgg16.h5', FILES_PATH+'vgg16.h5', cache_subdir='models')
model.load_weights(fpath)

# %% [markdown]
# ## Getting imagenet predictions
#
# The setup of the imagenet model is now complete, so all we have to do is grab a batch of images and call *predict()* on them.

# %%
batch_size = 4

# %% [markdown]
# Keras provides functionality to create batches of data from directories containing images; all we have to do is to define the size to resize the images to, what type of labels to create, whether to randomly shuffle the images, and how many images to include in each batch. We use this little wrapper to define some helpful defaults appropriate for imagenet data:

# %%
def get_batches(dirname, gen=image.ImageDataGenerator(), shuffle=True, 
                batch_size=batch_size, class_mode='categorical'):
    return gen.flow_from_directory(path+dirname, target_size=(224,224), 
                class_mode=class_mode, shuffle=shuffle, batch_size=batch_size)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-815f28f0b39d> in <module>()
# ----> 1 def get_batches(dirname, gen=image.ImageDataGenerator(), shuffle=True,
#       2                 batch_size=batch_size, class_mode='categorical'):
#       3     return gen.flow_from_directory(path+dirname, target_size=(224,224),
#       4                 class_mode=class_mode, shuffle=shuffle, batch_size=batch_size)
#
# NameError: name 'image' is not defined

# %% [markdown]
# From here we can use exactly the same steps as before to look at predictions from the model.

# %%
batches = get_batches('train', batch_size=batch_size)
val_batches = get_batches('valid', batch_size=batch_size)
imgs,labels = next(batches)

# This shows the 'ground truth'
plots(imgs, titles=labels)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-19c221fe497b> in <module>()
# ----> 1 batches = get_batches('train', batch_size=batch_size)
#       2 val_batches = get_batches('valid', batch_size=batch_size)
#       3 imgs,labels = next(batches)
#       4
#       5 # This shows the 'ground truth'
#
# NameError: name 'get_batches' is not defined

# %% [markdown]
# The VGG model returns 1,000 probabilities for each image, representing the probability that the model assigns to each possible imagenet category for each image. By finding the index with the largest probability (with *np.argmax()*) we can find the predicted label.

# %%
def pred_batch(imgs):
    preds = model.predict(imgs)
    idxs = np.argmax(preds, axis=1)

    print('Shape: {}'.format(preds.shape))
    print('First 5 classes: {}'.format(classes[:5]))
    print('First 5 probabilities: {}\n'.format(preds[0, :5]))
    print('Predictions prob/class: ')
    
    for i in range(len(idxs)):
        idx = idxs[i]
        print ('  {:.4f}/{}'.format(preds[i, idx], classes[idx]))

# %%
pred_batch(imgs)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-6-09fb28ea2265> in <module>()
# ----> 1 pred_batch(imgs)
#
# NameError: name 'imgs' is not defined
